# %%
import os

sample_futures_strategy_nm = "simple_momentum"

os.makedirs("/Users/seongmin/Desktop/neomatrix_trading", exist_ok=True)
os.makedirs("/Users/seongmin/Desktop/neomatrix_trading/module/", exist_ok=True)
os.makedirs("/Users/seongmin/Desktop/neomatrix_trading/module/futures/", exist_ok=True)
os.makedirs(f"//Users/seongmin/Desktop/neomatrix_trading/futures/{sample_futures_strategy_nm}", exist_ok=True)

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1ZZw4u3uImeuooj-v10VDX_utgEjsfVv4' -O /Users/seongmin/Desktop/neomatrix_trading/df_sample.csv # sample data

# system config
# !wget https://raw.githubusercontent.com/NeoMatrixAI/strategy/main/futures/futures_config.py -O /Users/seongmin/Desktop/neomatrix_trading/futures/futures_config.py

# sample strategy - simple_momentum
# !wget https://raw.githubusercontent.com/NeoMatrixAI/strategy/main/futures/simple_momentum/simple_momentum.py -O /Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum.py
# !wget https://raw.githubusercontent.com/NeoMatrixAI/strategy/main/futures/simple_momentum/simple_momentum_config.py -O /Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum_config.py

# module
# !wget https://raw.githubusercontent.com/NeoMatrixAI/nb-runner/main/module/log_viewer.py -O /Users/seongmin/Desktop/neomatrix_trading/module/log_viewer.py  # For real-time-trade logging
# !wget https://raw.githubusercontent.com/NeoMatrixAI/nb-runner/main/module/futures/position.py -O /Users/seongmin/Desktop/neomatrix_trading/module/futures/position.py  # position
# !wget https://raw.githubusercontent.com/NeoMatrixAI/nb-runner/main/module/futures/trade.py -O /Users/seongmin/Desktop/neomatrix_trading/module/futures/trade.py  # trade
# Out:
# --2025-09-18 17:24:57--  https://docs.google.com/uc?export=download&id=1ZZw4u3uImeuooj-v10VDX_utgEjsfVv4
# docs.google.com (docs.google.com) 해석 중... 142.250.207.110
# 다음으로 연결 중: docs.google.com (docs.google.com)|142.250.207.110|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 303 See Other
# 위치: https://drive.usercontent.google.com/download?id=1ZZw4u3uImeuooj-v10VDX_utgEjsfVv4&export=download [따라감]
# --2025-09-18 17:24:57--  https://drive.usercontent.google.com/download?id=1ZZw4u3uImeuooj-v10VDX_utgEjsfVv4&export=download
# drive.usercontent.google.com (drive.usercontent.google.com) 해석 중... 142.250.207.97
# 다음으로 연결 중: drive.usercontent.google.com (drive.usercontent.google.com)|142.250.207.97|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 397412 (388K) [application/octet-stream]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/df_sample.csv'
#
# /Users/seongmin/Des 100%[===================>] 388.10K  2.14MB/s    /  0.2s
#
# 2025-09-18 17:24:59 (2.14 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/df_sample.csv' 저장함 [397412/397412]
#
# --2025-09-18 17:24:59--  https://raw.githubusercontent.com/NeoMatrixAI/strategy/main/futures/futures_config.py
# raw.githubusercontent.com (raw.githubusercontent.com) 해석 중... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# 다음으로 연결 중: raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 808 [text/plain]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/futures/futures_config.py'
#
# /Users/seongmin/Des 100%[===================>]     808  --.-KB/s    /  0s
#
# 2025-09-18 17:24:59 (193 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/futures/futures_config.py' 저장함 [808/808]
#
# --2025-09-18 17:24:59--  https://raw.githubusercontent.com/NeoMatrixAI/strategy/main/futures/simple_momentum/simple_momentum.py
# raw.githubusercontent.com (raw.githubusercontent.com) 해석 중... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# 다음으로 연결 중: raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 2181 (2.1K) [text/plain]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum.py'
#
# /Users/seongmin/Des 100%[===================>]   2.13K  --.-KB/s    /  0s
#
# 2025-09-18 17:24:59 (35.9 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum.py' 저장함 [2181/2181]
#
# --2025-09-18 17:25:00--  https://raw.githubusercontent.com/NeoMatrixAI/strategy/main/futures/simple_momentum/simple_momentum_config.py
# raw.githubusercontent.com (raw.githubusercontent.com) 해석 중... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# 다음으로 연결 중: raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 250 [text/plain]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum_config.py'
#
# /Users/seongmin/Des 100%[===================>]     250  --.-KB/s    /  0s
#
# 2025-09-18 17:25:00 (26.5 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum_config.py' 저장함 [250/250]
#
# --2025-09-18 17:25:00--  https://raw.githubusercontent.com/NeoMatrixAI/nb-runner/main/module/log_viewer.py
# raw.githubusercontent.com (raw.githubusercontent.com) 해석 중... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# 다음으로 연결 중: raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 1964 (1.9K) [text/plain]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/module/log_viewer.py'
#
# /Users/seongmin/Des 100%[===================>]   1.92K  --.-KB/s    /  0s
#
# 2025-09-18 17:25:00 (36.0 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/module/log_viewer.py' 저장함 [1964/1964]
#
# --2025-09-18 17:25:00--  https://raw.githubusercontent.com/NeoMatrixAI/nb-runner/main/module/futures/position.py
# raw.githubusercontent.com (raw.githubusercontent.com) 해석 중... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# 다음으로 연결 중: raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 527 [text/plain]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/module/futures/position.py'
#
# /Users/seongmin/Des 100%[===================>]     527  --.-KB/s    /  0s
#
# 2025-09-18 17:25:00 (71.8 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/module/futures/position.py' 저장함 [527/527]
#
# --2025-09-18 17:25:00--  https://raw.githubusercontent.com/NeoMatrixAI/nb-runner/main/module/futures/trade.py
# raw.githubusercontent.com (raw.githubusercontent.com) 해석 중... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# 다음으로 연결 중: raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 1291 (1.3K) [text/plain]
# 저장 위치: `/Users/seongmin/Desktop/neomatrix_trading/module/futures/trade.py'
#
# /Users/seongmin/Des 100%[===================>]   1.26K  --.-KB/s    /  0s
#
# 2025-09-18 17:25:00 (246 MB/s) - `/Users/seongmin/Desktop/neomatrix_trading/module/futures/trade.py' 저장함 [1291/1291]

# %%
import os

base_dir = "/Users/seongmin/Desktop/neomatrix_trading"

# List of files to check
files_to_check = [
    f"{base_dir}/df_sample.csv",
    f"{base_dir}/module/log_viewer.py",
    f"{base_dir}/module/futures/position.py",
    f"{base_dir}/module/futures/trade.py",
    f"{base_dir}/futures/futures_config.py",
    f"{base_dir}/futures/simple_momentum/simple_momentum.py",
    f"{base_dir}/futures/simple_momentum/simple_momentum_config.py",
]

# Check if files exist
print("🔍 Checking downloaded files:")
for f in files_to_check:
    if os.path.exists(f):
        print(f"✅ Found: {f}")
    else:
        print(f"❌ Missing: {f}")
# Out:
# 🔍 Checking downloaded files:
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/df_sample.csv
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/module/log_viewer.py
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/module/futures/position.py
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/module/futures/trade.py
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/futures/futures_config.py
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum.py
# ✅ Found: /Users/seongmin/Desktop/neomatrix_trading/futures/simple_momentum/simple_momentum_config.py

# %%
import pandas as pd
df = pd.read_csv('/Users/seongmin/Desktop/neomatrix_trading/df_sample.csv').set_index('datetime')
df
# Out:
#                       BTCUSDT  ETHUSDT  XRPUSDT  BCHUSDT  LTCUSDT  ADAUSDT  \
# datetime
# 2025-06-24 00:00:00  101611.8  2272.55   2.0179   448.66    81.58   0.5471
# 2025-06-24 00:01:00  101750.0  2278.25   2.0213   449.19    81.68   0.5479
# 2025-06-24 00:02:00  101764.3  2279.07   2.0213   449.60    81.75   0.5481
# 2025-06-24 00:03:00  101900.9  2282.18   2.0238   450.06    81.93   0.5495
# 2025-06-24 00:04:00  101895.0  2281.94   2.0241   450.42    81.90   0.5498
# ...                       ...      ...      ...      ...      ...      ...
# 2025-06-26 23:55:00  107333.6  2442.85   2.1223   491.10    85.00   0.5550
# 2025-06-26 23:56:00  107412.3  2444.74   2.1237   491.43    84.94   0.5551
# 2025-06-26 23:57:00  107372.9  2443.48   2.1225   491.17    84.98   0.5551
# 2025-06-26 23:58:00  107406.2  2445.49   2.1227   491.90    85.05   0.5554
# 2025-06-26 23:59:00  107383.2  2444.99   2.1233   492.21    85.07   0.5552
#
#                      ETCUSDT  TRXUSDT  DOTUSDT  DOGEUSDT
# datetime
# 2025-06-24 00:00:00   15.524  0.27148    3.246   0.15363
# 2025-06-24 00:01:00   15.528  0.27149    3.253   0.15400
# 2025-06-24 00:02:00   15.548  0.27172    3.254   0.15401
# 2025-06-24 00:03:00   15.556  0.27169    3.260   0.15441
# 2025-06-24 00:04:00   15.581  0.27170    3.262   0.15451
# ...                      ...      ...      ...       ...
# 2025-06-26 23:55:00   16.194  0.27131    3.310   0.15971
# 2025-06-26 23:56:00   16.197  0.27132    3.310   0.15982
# 2025-06-26 23:57:00   16.199  0.27136    3.310   0.15980
# 2025-06-26 23:58:00   16.208  0.27139    3.311   0.15995
# 2025-06-26 23:59:00   16.207  0.27136    3.314   0.15994
#
# [4320 rows x 10 columns]

# %%
# example strategy, config
import futures.simple_momentum.simple_momentum as strategy       # Replace with your own strategy file
import futures.simple_momentum.simple_momentum_config as config  # Replace with your own config file

# run to verify strategy
config_dict = {'strategy_config': config.strategy_config}
weights = strategy.strategy(df, config_dict)
weights
# Out:
# {'BTCUSDT': np.float64(0.04418502459820163),
#  'ETHUSDT': np.float64(0.052915871480547993),
#  'BCHUSDT': np.float64(0.006335436564149946),
#  'LTCUSDT': np.float64(0.12265821180195226),
#  'ADAUSDT': np.float64(0.058384542481564376),
#  'ETCUSDT': np.float64(0.08757221346396134),
#  'TRXUSDT': np.float64(0.023018893231682238),
#  'DOTUSDT': np.float64(0.11139818172590331),
#  'DOGEUSDT': np.float64(0.0935316246520369),
#  'XRPUSDT': np.float64(-0.4)}

# %%
USER_KEY = "cc3948f0cd364a9f684a1fe78b9229ba"      #  Input your User key
DATA_KEY = "a71eaf04-802f-40be-93c2-5bee2548f4db"  #  Fixed Data Api key

print("USER_KEY:", USER_KEY if USER_KEY else "Not found")
print("DATA_KEY:", DATA_KEY if DATA_KEY else "Not found")
# Out:
# USER_KEY: cc3948f0cd364a9f684a1fe78b9229ba
# DATA_KEY: a71eaf04-802f-40be-93c2-5bee2548f4db

# %%
import requests

root_url = f'https://zipline.fin.cloud.ainode.ai/'
headers={"API-KEY": USER_KEY}
requests.get(root_url, headers=headers).json()
# Out:
# {'message': 'API Server is Running.', 'status': 200, 'User status': 'active'}

# %%
import os
strategy_name = "simple_momentum"

# Upload or Update strategy file
endpoint = 'upload/strategy'
url = root_url + endpoint

base_path = "/Users/seongmin/Desktop/neomatrix_trading/futures"
file_path = os.path.join(base_path, strategy_name, strategy_name + ".py")

params = {'tradeType':'futures', 'overwrite': True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())
# Out:
# 📂 Upload Response: {'message': "'simple_momentum' Strategy Updated Successfully!"}

# %%
# Check strategy file upload
endpoint = 'upload/check/strategy'
url = root_url + endpoint

params = {"tradeType": "futures", "strategy_name": strategy_name}

response = requests.get(url, headers=headers, params=params)
print(response.json()['content'])
# Out:
# # strategy.py
# import pandas as pd
# import numpy as np
#
# def strategy(df, config_dict):
#     # --- Input validation ---
#     if not isinstance(df, pd.DataFrame):
#         raise TypeError("Input must be a pandas DataFrame.")
#     if df.empty:
#         raise ValueError("Input DataFrame is empty.")
#     if not isinstance(config_dict, dict):
#         raise TypeError("config_dict must be a dictionary.")
#
#     # --- Load strategy-specific config ---
#     strategy_specific_config = config_dict.get("strategy_config", {})
#     lookback = strategy_specific_config.get("lookback", 20)
#     long_allocation_pct = strategy_specific_config.get("long_allocation_pct", 0.7)
#     short_allocation_pct = strategy_specific_config.get("short_allocation_pct", 0.3)
#
#     if long_allocation_pct + short_allocation_pct > 1.0:
#         raise ValueError("Sum of long and short allocation percentages cannot exceed 1.0")
#
#     # --- Momentum calculation ---
#     momentum_scores = {}
#     for symbol in df.columns:
#         series = df[symbol].dropna()
#         if len(series) < lookback + 1:
#             continue
#         # momentum = current price / price lookback periods ago - 1
#         momentum = series.iloc[-1] / series.iloc[-lookback] - 1
#         momentum_scores[symbol] = momentum
#
#     if not momentum_scores:
#         return {}
#
#     # --- Split into long and short candidates ---
#     longs = {s: m for s, m in momentum_scores.items() if m > 0}
#     shorts = {s: abs(m) for s, m in momentum_scores.items() if m < 0}
#
#     weights = {}
#
#     # --- Allocate longs proportionally ---
#     if longs:
#         long_total = sum(longs.values())
#         for s, m in longs.items():
#             weights[s] = (m / long_total) * long_allocation_pct
#
#     # --- Allocate shorts proportionally ---
#     if shorts:
#         short_total = sum(shorts.values())
#         for s, m in shorts.items():
#             weights[s] = -(m / short_total) * short_allocation_pct
#
#     # --- Final check: ensure sum(|weights|) ≤ 1.0 ---
#     total_abs = sum(abs(w) for w in weights.values())
#
#     if total_abs > 1.0:
#         # Normalize to fit within 1.0
#         for s in weights:
#             weights[s] = weights[s] / total_abs
#
#     return weights

# %%
# Strategy configs
strategy_config_params = {
  "rebalancing_config": {             # Rebalancing settings
    "rebalancing_interval_hours": 72, ## Rebalancing cycle (choose between 6, 12, 24, and 72 hours)
  },
  "strategy_config": {
    "lookback": 60,              # Lookback period for momentum calculation
    "long_allocation_pct": 0.6,  # Proportion of capital allocated to longs
    "short_allocation_pct": 0.4  # Proportion of capital allocated to shorts
    }
}

# %%
# System configs
start_date_str = "2025-08-01"
end_date_str = "2025-08-30"
lookback_min = 60 # Max lookback minutes the script needs for data history
initial_capital = 10000000
leverage = 100
symbols = ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT',
           'ADAUSDT', 'ETCUSDT', 'TRXUSDT', 'DOTUSDT', 'DOGEUSDT']

generate_report_flag = True

# %%
import json
from datetime import datetime

path = "/Users/seongmin/Desktop/neomatrix_trading/backtest_report"

request_payload = {
    "data_apikey": DATA_KEY,
    "strategy": strategy_name,
    "strategy_config": strategy_config_params,
    "start_date": start_date_str,
    "end_date": end_date_str,
    "lookback_minutes": lookback_min,
    "capital": initial_capital,
    "leverage": leverage,
    "symbols": symbols,
    "calendar": "24/7",
    "frequency": "minute",
    "generate_pyfolio_report": generate_report_flag
}

endpoint = '/run/futures/backtest'
url = root_url + endpoint

try:
    response = requests.post(url, json=request_payload, headers=headers)
    response.raise_for_status()
    print(f"\n--- Backtest execution successful (Status Code: {response.status_code}) ---")

    try:
        result_data = response.json()
        report_type = result_data.get('report_type') # Check report type

        if report_type == 'html':
            print("Report Type: HTML Report included.")
            html_content = result_data.get('html_content')
            logs = result_data.get('logs', 'No stderr logs received.')
            stdout_logs = result_data.get('stdout', 'No stdout received.')

            if html_content:
                if not os.path.exists(path):
                    os.makedirs(path)

                report_filename = os.path.join(path, f"{datetime.now().strftime('%Y-%m-%d %H:%M')}_{strategy_name}_backtest_report.html")
                try:
                    with open(report_filename, "w", encoding="utf-8") as f:
                        f.write(html_content)
                    print(f"HTML report received and saved successfully as '{report_filename}'.")
                except Exception as e:
                    print(f"ERROR: Failed to save received HTML report: {e}")
                    print("\n--- Received HTML Content (Snippet) ---")
                    print(html_content[:1000] + "...") # Output some content when saving fails
            else:
                print("WARN: Report type was 'html' but no HTML content found in response.")

            # print logging
            print("\n--- Execution Logs (stderr) ---")
            print(logs)
            if stdout_logs:
                print("\n--- Execution Output (stdout) ---")
                print(stdout_logs)

        elif report_type == 'logs_only':
            print(f"Report Type: Logs Only (Report generation skipped).")
            print(f"Message: {result_data.get('message')}")
            print("\n--- Execution Logs (stderr) ---")
            print(result_data.get('logs', 'No stderr logs received.'))
            if 'stdout' in result_data:
                 print("\n--- Execution Output (stdout) ---")
                 print(result_data.get('stdout', 'No stdout received.'))
        else:
            print(f"WARN: Received successful response with unknown report_type: '{report_type}'")
            print("\n--- Full JSON Response ---")
            print(json.dumps(result_data, indent=2, ensure_ascii=False))

    except json.JSONDecodeError:
        print("ERROR: Failed to decode JSON response from successful API call.")
        print(f"Content-Type: {response.headers.get('content-type', 'N/A')}")
        print("\n--- Received Raw Content (First 1000 chars) ---")
        print(response.text[:1000] + "...")

except requests.exceptions.Timeout:
    print(f"\n--- API call failed: Timeout) ---")
except requests.exceptions.HTTPError as e:
    print(f"\n--- API call failed: HTTP Error {e.response.status_code} ---")
    try:
        error_details = e.response.json()
        print("Error details:")
        print(json.dumps(error_details, indent=2, ensure_ascii=False))
    except json.JSONDecodeError:
        print("Error response content (Non-JSON):")
        print(e.response.text)
except requests.exceptions.RequestException as e:
    print(f"\n--- API call failure: Request Error ---")
    print(f"Error connecting to or requesting the API server ({url}): {e}")
except Exception as e:
    print(f"\n--- Unexpected error occurred ---")
    print(f"Error type: {type(e).__name__}, Content: {e}")
# Out:
# --- Backtest execution successful (Status Code: 200) ---
# Report Type: HTML Report included.
# HTML report received and saved successfully as '/Users/seongmin/Desktop/neomatrix_trading/backtest_report/2025-09-18 17:30_simple_momentum_backtest_report.html'.
#
# --- Execution Logs (stderr) ---
# [2025-09-18 08:28:47+0000] Backtest script execution started.
# INFO: Command line arguments parsed.
#
# --- Runtime Configuration ---
#   - user_key: Provided (Masked)
#   - data_apikey: Provided (Masked)
#   - strategy_config_json: Provided (Number of parameters: 20)
#   - start_date: 2025-08-01
#   - end_date: 2025-08-30
#   - lookback_minutes: 60
#   - capital: 10000000.0
#   - leverage: 100.0
#   - symbols: ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT', 'DOTUSDT', 'DOGEUSDT']
#   - calendar: 24/7
#   - frequency: minute
#   - output_file: /app/backtest/temp_backtest_results/pyfolio_report_943a965b-9348-4c0f-bd34-61f05bea45e3.html
#   - generate_report: True
# -----------------------------
# INFO: Loading dynamic strategy and parsing config...
# INFO: Dynamic strategy loaded successfully from 'simple_momentum.py'.
# INFO: Preparing backtest parameters...
# INFO: Starting custom data fetching for 10 symbols...
# INFO: Data Fetching Complete. Fetched data for 10/10 symbols. Duration: 0:00:15.730801
# INFO: Starting backtest engine (run_algorithm_custom_data)...
#   - Initial Capital: 10000000.00, Leverage: 100.0, Backtest Capital Base: 1000000000.00
#
# --- Backtesting start ---
#
# [2025-08-01 00:00:00+00:00] Initialize function executed.
# [2025-08-01 00:00:00+00:00] - Loaded strategy config keys: ['rebalancing_config', 'strategy_config']
#  - Interpreted strategy/execution settings: Interval=72h, Lookback=60m
# [2025-08-01 00:00:00+00:00] Set rebalancing schedule (period: 72 hours)
# [2025-08-01 00:00:00+00:00] - Initialize complete.
# ]2025-08-01 00:00:00+00:00] - [initialize] (Current State: IDLE)
# [2025-08-01 00:00:00+00:00] - [handle_data] (Current State: IDLE)
# [2025-08-01 00:00:00+00:00] - [clear_positions] No action taken. (Current State: IDLE)
# [2025-08-01 00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1000000000.00
# [2025-08-01 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-01 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-01 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-01 00:01:00+00:00] - [rebalance] Strategy results: Long=0, Short=10
# 2025-08-01 00:01:00+00:00 - [rebalance] long_candidates : {}
# 2025-08-01 00:01:00+00:00 - [rebalance] short_candidates : {'BTCUSDT': -0.015010593478650462, 'ETHUSDT': -0.03632969331413071, 'XRPUSDT': -0.04545550621138444, 'BCHUSDT': -0.044478815902455865, 'LTCUSDT': -0.0223952432702845, 'ADAUSDT': -0.05746927505866788, 'ETCUSDT': -0.048553863656341935, 'TRXUSDT': -0.01330119104187314, 'DOTUSDT': -0.06432176788320798, 'DOGEUSDT': -0.052684050183003095}
# BTCUSDT -> SHORT Target Position: -127.13376
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> SHORT Target Position: -9625.41717
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> SHORT Target Position: -14716711.30618
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> SHORT Target Position: -77658.34291
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> SHORT Target Position: -205347.91189
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> SHORT Target Position: -75867029.78042
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> SHORT Target Position: -2289304.71292
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> SHORT Target Position: -40663989.73364
# [DEBUG] TRXUSDT Current position quantity: 0
# DOTUSDT -> SHORT Target Position: -17097758.60798
# [DEBUG] DOTUSDT Current position quantity: 0
# DOGEUSDT -> SHORT Target Position: -244190267.36039
# [DEBUG] DOGEUSDT Current position quantity: 0
# [2025-08-01 00:01:00+00:00] - [rebalance] New positions set.
# ------------------------------------------------------------
# [2025-08-04 00:00:00+00:00] - [clear_positions] Clearing all positions. (Current State: REBALANCED)
# [2025-08-04 00:00:00+00:00] - [clear_positions] Clearing: ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT', 'DOTUSDT', 'DOGEUSDT']
# Clear - BTCUSDT: Position: 127, Value: 14440103.20, Price: 113701.6
# Clear - ETHUSDT: Position: 9625, Value: 33373628.75, Price: 3467.39
# Clear - XRPUSDT: Position: 14716711, Value: 42373825.98, Price: 2.8793
# Clear - BCHUSDT: Position: 77658, Value: 41835917.76, Price: 538.72
# Clear - LTCUSDT: Position: 205347, Value: 22405411.17, Price: 109.11
# Clear - ADAUSDT: Position: 75867029, Value: 54851861.97, Price: 0.723
# Clear - ETCUSDT: Position: 2289304, Value: 45064949.24, Price: 19.685
# Clear - TRXUSDT: Position: 40663989, Value: 13235721.78, Price: 0.32549
# Clear - DOTUSDT: Position: 17097758, Value: 61175778.12, Price: 3.578
# Clear - DOGEUSDT: Position: 244190267, Value: 48410720.43, Price: 0.19825
# [2025-08-04 00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 977012990.09
# [2025-08-04 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-04 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-04 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-04 00:01:00+00:00] - [rebalance] Strategy results: Long=4, Short=6
# 2025-08-04 00:01:00+00:00 - [rebalance] long_candidates : {'XRPUSDT': 0.14029935655619888, 'LTCUSDT': 0.013444487629576845, 'ADAUSDT': 0.21350278906200043, 'TRXUSDT': 0.2327533667522237}
# 2025-08-04 00:01:00+00:00 - [rebalance] short_candidates : {'BTCUSDT': -0.0440120698868603, 'ETHUSDT': -0.12745312547278367, 'BCHUSDT': -0.12169898707600886, 'ETCUSDT': -0.012562970100422021, 'DOTUSDT': -0.08596176451958877, 'DOGEUSDT': -0.008311082944336322}
# BTCUSDT -> SHORT Target Position: -378.15269
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> SHORT Target Position: -35928.52534
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> LONG Target Position: 47588625.63805
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> SHORT Target Position: -220847.09845
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> LONG Target Position: 120382.59275
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> LONG Target Position: 288343191.70819
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> SHORT Target Position: -624254.59650
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> LONG Target Position:
# [2025-08-28 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-28 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-28 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-28 00:01:00+00:00] - [rebalance] Strategy results: Long=10, Short=0
# 2025-08-28 00:01:00+00:00 - [rebalance] long_candidates : {'BTCUSDT': 0.020023078693281997, 'ETHUSDT': 0.03904164734627979, 'XRPUSDT': 0.014225369243497907, 'BCHUSDT': 0.0870883423249225, 'LTCUSDT': 0.056037029113840425, 'ADAUSDT': 0.10048913426474167, 'ETCUSDT': 0.0998625670953159, 'TRXUSDT': 0.021279617178274646, 'DOTUSDT': 0.1029958421892933, 'DOGEUSDT': 0.058957372550551834}
# 2025-08-28 00:01:00+00:00 - [rebalance] short_candidates : {}
# BTCUSDT -> LONG Target Position: 190.69675
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> LONG Target Position: 9005.60393
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> LONG Target Position: 5038257.61038
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> LONG Target Position: 165897.31925
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> LONG Target Position: 525282.11832
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> LONG Target Position: 122943197.76020
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> LONG Target Position: 4872280.17434
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> LONG Target Position: 64688448.66511
# [DEBUG] TRXUSDT Current position quantity: 0
# DOTUSDT -> LONG Target Position: 28052385.01987
# [DEBUG] DOTUSDT Current position quantity: 0
# DOGEUSDT -> LONG Target Position: 284483415.22420
# [DEBUG] DOGEUSDT Current position quantity: 0
# [2025-08-28 00:01:00+00:00] - [rebalance] New positions set.
# ------------------------------------------------------------
#
# --- Backtesting end ---
#
# --- Start of backtest analysis ---
# Final portfolio value: 1038044608.64
#
# --- Detailed analysis metrics (API call) ---
# Cumulative Return (API): 0.03804 (3.804%)
# Daily Sharpe Ratio (API): 0.065
# Monthly Sharpe Ratio (API): 0.355
# Annual Sharpe Ratio (API): 0.002
# Maximum drop (API): -0.10537 (-10.537%)
#
# --- Detailed Analysis Indicator (Empyrical) ---
# Sharp Ratio (Empyrical, annualized): 0.002
# Maximum drop (Empyrical): -0.10537 (-10.537%)
#
# --- End of backtest analysis ---
# INFO: Backtest engine run completed successfully. Duration: 0:00:39.655216
# INFO: Starting report generation...
#   - Saving HTML report
# INFO: HTML report generated successfully. Duration: 0:00:21.637274
# [2025-09-18 08:30:05+0000] Backtest script execution completed successfully. Total time: 0:01:17.225963
#
# --- Execution Output (stdout) ---
# - strategy: simple_momentum.py

# %%
import requests

root_url = f'https://aifapbt.fin.cloud.ainode.ai/'

headers = {"API-KEY": USER_KEY}
requests.get(root_url, headers=headers).json()
# Out:
# {'message': 'API Server is Running.',
#  'status': 200,
#  'User status': 'active',
#  'Expires At': '2025-09-24T00:00:00',
#  'Level': 1}

# %%
import os
strategy_name = "simple_momentum"

# Upload or Update strategy file
endpoint = 'upload/strategy'
url = root_url + endpoint

base_path = "/Users/seongmin/Desktop/neomatrix_trading/futures"
file_path = os.path.join(base_path, strategy_name, strategy_name + ".py")

params = {'tradeType':'futures', 'overwrite': True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())
# Out:
# 📂 Upload Response: {'message': "'simple_momentum' Strategy Updated Successfully!"}

# %%
# Check strategy file upload
endpoint = 'upload/check/strategy'
url = root_url + endpoint

params = {"tradeType": "futures", "strategy_name": strategy_name}

response = requests.get(url, headers=headers, params=params)
print(response.json()['content'])
# Out:
# # strategy.py
# import pandas as pd
# import numpy as np
#
# def strategy(df, config_dict):
#     # --- Input validation ---
#     if not isinstance(df, pd.DataFrame):
#         raise TypeError("Input must be a pandas DataFrame.")
#     if df.empty:
#         raise ValueError("Input DataFrame is empty.")
#     if not isinstance(config_dict, dict):
#         raise TypeError("config_dict must be a dictionary.")
#
#     # --- Load strategy-specific config ---
#     strategy_specific_config = config_dict.get("strategy_config", {})
#     lookback = strategy_specific_config.get("lookback", 20)
#     long_allocation_pct = strategy_specific_config.get("long_allocation_pct", 0.7)
#     short_allocation_pct = strategy_specific_config.get("short_allocation_pct", 0.3)
#
#     if long_allocation_pct + short_allocation_pct > 1.0:
#         raise ValueError("Sum of long and short allocation percentages cannot exceed 1.0")
#
#     # --- Momentum calculation ---
#     momentum_scores = {}
#     for symbol in df.columns:
#         series = df[symbol].dropna()
#         if len(series) < lookback + 1:
#             continue
#         # momentum = current price / price lookback periods ago - 1
#         momentum = series.iloc[-1] / series.iloc[-lookback] - 1
#         momentum_scores[symbol] = momentum
#
#     if not momentum_scores:
#         return {}
#
#     # --- Split into long and short candidates ---
#     longs = {s: m for s, m in momentum_scores.items() if m > 0}
#     shorts = {s: abs(m) for s, m in momentum_scores.items() if m < 0}
#
#     weights = {}
#
#     # --- Allocate longs proportionally ---
#     if longs:
#         long_total = sum(longs.values())
#         for s, m in longs.items():
#             weights[s] = (m / long_total) * long_allocation_pct
#
#     # --- Allocate shorts proportionally ---
#     if shorts:
#         short_total = sum(shorts.values())
#         for s, m in shorts.items():
#             weights[s] = -(m / short_total) * short_allocation_pct
#
#     # --- Final check: ensure sum(|weights|) ≤ 1.0 ---
#     total_abs = sum(abs(w) for w in weights.values())
#
#     if total_abs > 1.0:
#         # Normalize to fit within 1.0
#         for s in weights:
#             weights[s] = weights[s] / total_abs
#
#     return weights

# %%
# Upload or Update strategy-config file
endpoint = 'upload/strategy-config'
url = root_url + endpoint

strategy_config_name = strategy_name + "_config"
base_path = "/Users/seongmin/Desktop/neomatrix_trading/futures/"
file_path = os.path.join(base_path, strategy_name, strategy_config_name + ".py")

params = {"tradeType": "futures", "overwrite": True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())
# Out:
# 📂 Upload Response: {'message': "'simple_momentum' Strategy-Config Updated Successfully!"}

# %%
# Check strategy-config file upload
endpoint = 'upload/check/strategy-config'
url = root_url + endpoint

params = {"tradeType": "futures", "strategy_name": strategy_name}

response = requests.get(url, headers=headers, params=params)
print(response.json()['content'])
# Out:
# strategy_config = {
#     "lookback": 60,              # Lookback period for momentum calculation
#     "long_allocation_pct": 0.6,  # Proportion of capital allocated to longs
#     "short_allocation_pct": 0.4  # Proportion of capital allocated to shorts
# }

# %%
# Upload or Update system-config file
endpoint = "upload/system-config"
url = root_url + endpoint

system_config_name = "futures_config"
base_path = "/Users/seongmin/Desktop/neomatrix_trading/futures"
file_path = os.path.join(base_path, system_config_name + ".py")

params = {"tradeType": "futures", "overwrite": True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())
# Out:
# 📂 Upload Response: {'message': "'Futures' System-Config Updated Successfully!"}

# %%
# Check system-config file upload
endpoint = "upload/check/system-config"
url = root_url + endpoint

params = {"tradeType": "futures"}

response = requests.get(url, headers=headers, params=params)
print(response.json()['content'])
# Out:
# # ==========================
# # Required System Settings
# # ==========================
# system_config = {
#     "data_apikey": "a71eaf04-802f-40be-93c2-5bee2548f4db",
#     "tz_str": "Asia/Seoul",
#     "timeframe": "1min",
#     "orderType": "market",
#     "base_symbol": "BTCUSDT",
#     "productType": "usdt-futures",
#     "posMode": "hedge_mode",
#     "holdSide": "long",
#     "marginMode": "crossed",
#     "marginCoin": "usdt",
#     "symbols": ['BTCUSDT', 'ETHUSDT', 'LTCUSDT', 'TRXUSDT', 'DOTUSDT', 'DOGEUSDT', 'XRPUSDT', 'BCHUSDT', 'ADAUSDT'],
#     "leverage": 5,
#     "trading_hours": 6,
#     "total_allocation": 0.4,
# }
#
#
# # ==========================
# # Rebalancing Trade Parameters
# # ==========================
# rebalancing_config = {
#     "rebalancing_interval_hours": 1, # Rebalancing cycle (hours)
# }

# %%
# run-system
endpoint = 'command/run-system'
url = root_url + endpoint

data = {
    "tradeType": "futures",
    "strategy_name": strategy_name,
    "trade_mode": "rebalancing",
    "trade_env": "live"
}

response = requests.post(url, headers=headers, json=data)

try:
    session_id = response.json()['session_id']
    print('session_id :',response.json()['session_id'])
    print('dashboard :',response.json()['dashboard_url'])
except:
    print('Error :',response.json()['message']['message'])

    session_id = response.json()['message']['session_id']
    print('session_id id :',session_id)

    print('dashboard :',response.json()['message']['dashboard_url'])
# Out:
# session_id : 6df40ec9
# dashboard : https://aifapbt.fin.cloud.ainode.ai/dashboard/live_futures_trading_dashbaord.html

# %%
# Terminate process
# You must execute terminate to force liquidation of the current process.
endpoint = 'command/terminate'
url = root_url + endpoint

params = {"session_id": f"{session_id}", "tradeType": 'futures'}

response = requests.get(url, headers=headers, params=params)
print(response.json())

# %%
from drive.MyDrive.NeoMatrixAI.module.futures import position, trade
df_all_position = position.all_positions(USER_KEY, 'usdt-futures', 'USDT')
df_all_position
