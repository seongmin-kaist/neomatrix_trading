# %%
USER_KEY = "cc3948f0cd364a9f684a1fe78b9229ba"      #  Input your User key
DATA_KEY = "a71eaf04-802f-40be-93c2-5bee2548f4db"  #  Fixed Data Api key

print("USER_KEY:", USER_KEY if USER_KEY else "Not found")
print("DATA_KEY:", DATA_KEY if DATA_KEY else "Not found")
# Out:
# USER_KEY: cc3948f0cd364a9f684a1fe78b9229ba
# DATA_KEY: a71eaf04-802f-40be-93c2-5bee2548f4db

# %%
import requests

root_url = f'https://zipline.fin.cloud.ainode.ai/'
headers={"API-KEY": USER_KEY}
requests.get(root_url, headers=headers).json()
# Out:
# {'message': 'API Server is Running.', 'status': 200, 'User status': 'active'}

# %%
import os
strategy_name = "simple_volatility"

# Upload or Update strategy file
endpoint = 'upload/strategy'
url = root_url + endpoint

base_path = "/Users/seongmin/Desktop/neomatrix_trading/futures"
file_path = os.path.join(base_path, strategy_name, strategy_name + ".py")

params = {'tradeType':'futures', 'overwrite': True} # If overwrite is True, it will modify the existing file.

with open(file_path, "rb") as f:
    files = {"file": f}
    response = requests.post(url, headers=headers, params=params, files=files)

print("📂 Upload Response:", response.json())
# Out:
# 📂 Upload Response: {'message': "'simple_volatility' Strategy Updated Successfully!"}

# %%
# Check strategy file upload
endpoint = 'upload/check/strategy'
url = root_url + endpoint

params = {"tradeType": "futures", "strategy_name": strategy_name}

response = requests.get(url, headers=headers, params=params)
print(response.json()['content'])
# Out:
# # strategy.py
# import pandas as pd
# import numpy as np
#
# def strategy(df, config_dict):
#     """
#     Develops a momentum signal adjusted for volatility.
#     The signal is the raw momentum divided by recent volatility.
#     """
#     # --- Input validation ---
#     if not isinstance(df, pd.DataFrame):
#         raise TypeError("Input must be a pandas DataFrame.")
#     if df.empty:
#         raise ValueError("Input DataFrame is empty.")
#     if not isinstance(config_dict, dict):
#         raise TypeError("config_dict must be a dictionary.")
#
#     # --- Load strategy-specific config ---
#     strategy_specific_config = config_dict.get("strategy_config", {})
#     momentum_lookback = strategy_specific_config.get("momentum_lookback", 60)
#     volatility_lookback = strategy_specific_config.get("volatility_lookback", 20)
#
#     # --- Signal Calculation ---
#     signals = {}
#
#     for symbol in df.columns:
#         series = df[symbol].dropna()
#
#         # Ensure there's enough data for both momentum and volatility calculations
#         if len(series) < momentum_lookback + 1 or len(series) < volatility_lookback + 1:
#             continue
#
#         # --- Calculate Raw Momentum ---
#         # Momentum is the return over the last `momentum_lookback` hours
#         price_now = series.iloc[-1]
#         price_then = series.iloc[-(momentum_lookback + 1)]
#
#         if price_then == 0:
#             continue # Avoid division by zero
#         raw_momentum = (price_now / price_then) - 1
#
#         # --- Calculate Volatility ---
#         # Volatility is the standard deviation of hourly returns over the last `volatility_lookback` hours
#         # We need `volatility_lookback + 1` prices to calculate `volatility_lookback` returns
#         recent_prices = series.iloc[-(volatility_lookback + 1):]
#         hourly_returns = recent_prices.pct_change().dropna()
#
#         # Ensure there are returns to calculate standard deviation on
#         if hourly_returns.empty:
#             continue
#
#         volatility = hourly_returns.std()
#
#         # --- Calculate Final Signal ---
#         # The final signal is the momentum adjusted for volatility
#         # If volatility is zero, the signal is undefined; we set it to zero to avoid errors
#         if volatility > 0:
#             signals[symbol] = raw_momentum / volatility
#         else:
#             signals[symbol] = 0.0
#
#     if not signals:
#         return {}
#
#     # --- Weight Allocation ---
#     # Normalize signals so that the sum of absolute weights equals 1.0
#     total_abs_signal = sum(abs(s) for s in signals.values())
#
#     if total_abs_signal == 0:
#         return {}
#
#     weights = {s: sig / total_abs_signal for s, sig in signals.items()}
#
#     return weights

# %%
strategy_config_params = {
  "rebalancing_config": {
    "rebalancing_interval_hours": 72, ## Rebalancing cycle (choose between 6, 12, 24, and 72 hours)
  },
  "strategy_config": {
    "momentum_lookback": 60,   # Lookback period in hours for the raw momentum calculation
    "volatility_lookback": 20  # Lookback period in hours for the volatility calculation
  }
}

# %%
# System configs
start_date_str = "2025-08-01"
end_date_str = "2025-08-30"
lookback_min = 60 # Max lookback minutes the script needs for data history
initial_capital = 10000000
leverage = 100
symbols = ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 
        'ADAUSDT', 'ETCUSDT', 'TRXUSDT']

generate_report_flag = True

# %%
import json
from datetime import datetime

path = "/Users/seongmin/Desktop/neomatrix_trading/backtest_report"

request_payload = {
    "data_apikey": DATA_KEY,
    "strategy": strategy_name,
    "strategy_config": strategy_config_params,
    "start_date": start_date_str,
    "end_date": end_date_str,
    "lookback_minutes": lookback_min,
    "capital": initial_capital,
    "leverage": leverage,
    "symbols": symbols,
    "calendar": "24/7",
    "frequency": "minute",
    "generate_pyfolio_report": generate_report_flag
}

endpoint = '/run/futures/backtest'
url = root_url + endpoint

try:
    response = requests.post(url, json=request_payload, headers=headers)
    response.raise_for_status()
    print(f"\n--- Backtest execution successful (Status Code: {response.status_code}) ---")

    try:
        result_data = response.json()
        report_type = result_data.get('report_type') # Check report type

        if report_type == 'html':
            print("Report Type: HTML Report included.")
            html_content = result_data.get('html_content')
            logs = result_data.get('logs', 'No stderr logs received.')
            stdout_logs = result_data.get('stdout', 'No stdout received.')

            if html_content:
                if not os.path.exists(path):
                    os.makedirs(path)

                report_filename = os.path.join(path, f"{datetime.now().strftime('%Y-%m-%d %H:%M')}_{strategy_name}_backtest_report.html")
                try:
                    with open(report_filename, "w", encoding="utf-8") as f:
                        f.write(html_content)
                    print(f"HTML report received and saved successfully as '{report_filename}'.")
                except Exception as e:
                    print(f"ERROR: Failed to save received HTML report: {e}")
                    print("\n--- Received HTML Content (Snippet) ---")
                    print(html_content[:1000] + "...") # Output some content when saving fails
            else:
                print("WARN: Report type was 'html' but no HTML content found in response.")

            # print logging
            print("\n--- Execution Logs (stderr) ---")
            print(logs)
            if stdout_logs:
                print("\n--- Execution Output (stdout) ---")
                print(stdout_logs)

        elif report_type == 'logs_only':
            print(f"Report Type: Logs Only (Report generation skipped).")
            print(f"Message: {result_data.get('message')}")
            print("\n--- Execution Logs (stderr) ---")
            print(result_data.get('logs', 'No stderr logs received.'))
            if 'stdout' in result_data:
                 print("\n--- Execution Output (stdout) ---")
                 print(result_data.get('stdout', 'No stdout received.'))
        else:
            print(f"WARN: Received successful response with unknown report_type: '{report_type}'")
            print("\n--- Full JSON Response ---")
            print(json.dumps(result_data, indent=2, ensure_ascii=False))

    except json.JSONDecodeError:
        print("ERROR: Failed to decode JSON response from successful API call.")
        print(f"Content-Type: {response.headers.get('content-type', 'N/A')}")
        print("\n--- Received Raw Content (First 1000 chars) ---")
        print(response.text[:1000] + "...")

except requests.exceptions.Timeout:
    print(f"\n--- API call failed: Timeout) ---")
except requests.exceptions.HTTPError as e:
    print(f"\n--- API call failed: HTTP Error {e.response.status_code} ---")
    try:
        error_details = e.response.json()
        print("Error details:")
        print(json.dumps(error_details, indent=2, ensure_ascii=False))
    except json.JSONDecodeError:
        print("Error response content (Non-JSON):")
        print(e.response.text)
except requests.exceptions.RequestException as e:
    print(f"\n--- API call failure: Request Error ---")
    print(f"Error connecting to or requesting the API server ({url}): {e}")
except Exception as e:
    print(f"\n--- Unexpected error occurred ---")
    print(f"Error type: {type(e).__name__}, Content: {e}")
# Out:
# --- Backtest execution successful (Status Code: 200) ---
# Report Type: HTML Report included.
# HTML report received and saved successfully as '/Users/seongmin/Desktop/neomatrix_trading/backtest_report/2025-09-18 18:54_simple_volatility_backtest_report.html'.
#
# --- Execution Logs (stderr) ---
# [2025-09-18 09:53:25+0000] Backtest script execution started.
# INFO: Command line arguments parsed.
#
# --- Runtime Configuration ---
#   - user_key: Provided (Masked)
#   - data_apikey: Provided (Masked)
#   - strategy_config_json: Provided (Number of parameters: 20)
#   - start_date: 2025-08-01
#   - end_date: 2025-08-30
#   - lookback_minutes: 60
#   - capital: 10000000.0
#   - leverage: 100.0
#   - symbols: ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT']
#   - calendar: 24/7
#   - frequency: minute
#   - output_file: /app/backtest/temp_backtest_results/pyfolio_report_e31a7238-a66d-49f3-b871-7ec709c0fc94.html
#   - generate_report: True
# -----------------------------
# INFO: Loading dynamic strategy and parsing config...
# INFO: Dynamic strategy loaded successfully from 'simple_volatility.py'.
# INFO: Preparing backtest parameters...
# INFO: Starting custom data fetching for 8 symbols...
# INFO: Data Fetching Complete. Fetched data for 8/8 symbols. Duration: 0:00:12.864527
# INFO: Starting backtest engine (run_algorithm_custom_data)...
#   - Initial Capital: 10000000.00, Leverage: 100.0, Backtest Capital Base: 1000000000.00
#
# --- Backtesting start ---
#
# [2025-08-01 00:00:00+00:00] Initialize function executed.
# [2025-08-01 00:00:00+00:00] - Loaded strategy config keys: ['rebalancing_config', 'strategy_config']
#  - Interpreted strategy/execution settings: Interval=72h, Lookback=60m
# [2025-08-01 00:00:00+00:00] Set rebalancing schedule (period: 72 hours)
# [2025-08-01 00:00:00+00:00] - Initialize complete.
# ]2025-08-01 00:00:00+00:00] - [initialize] (Current State: IDLE)
# [2025-08-01 00:00:00+00:00] - [handle_data] (Current State: IDLE)
# [2025-08-01 00:00:00+00:00] - [clear_positions] No action taken. (Current State: IDLE)
# [2025-08-01 00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1000000000.00
# [2025-08-01 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-01 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-01 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-01 00:01:00+00:00] - [rebalance] Strategy results: Long=0, Short=8
# 2025-08-01 00:01:00+00:00 - [rebalance] long_candidates : {}
# 2025-08-01 00:01:00+00:00 - [rebalance] short_candidates : {'BTCUSDT': -0.10370399812250786, 'ETHUSDT': -0.14311957408063034, 'XRPUSDT': -0.1430284542251465, 'BCHUSDT': -0.15186789073842352, 'LTCUSDT': -0.0683535632822711, 'ADAUSDT': -0.15048165791494547, 'ETCUSDT': -0.13644573391294448, 'TRXUSDT': -0.1029991277231307}
# BTCUSDT -> SHORT Target Position: -878.33161
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> SHORT Target Position: -37918.99905
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> SHORT Target Position: -46307007.55177
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> SHORT Target Position: -265155.63638
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> SHORT Target Position: -626751.90980
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> SHORT Target Position: -198655654.01313
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> SHORT Target Position:
00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1053508121.22
# [2025-08-10 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-10 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-10 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-10 00:01:00+00:00] - [rebalance] Strategy results: Long=7, Short=1
# 2025-08-10 00:01:00+00:00 - [rebalance] long_candidates : {'BTCUSDT': 0.050571289042794565, 'ETHUSDT': 0.3589139478546108, 'XRPUSDT': 0.1863402793947767, 'LTCUSDT': 0.028815581132776193, 'ADAUSDT': 0.21090756550248752, 'ETCUSDT': 0.11746731437876007, 'TRXUSDT': 0.025957641814035034}
# 2025-08-10 00:01:00+00:00 - [rebalance] short_candidates : {'BCHUSDT': -0.021026380879759277}
# BTCUSDT -> LONG Target Position: 455.56174
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> LONG Target Position: 90024.12807
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> LONG Target Position: 59634875.01079
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> SHORT Target Position: -38701.92084
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> LONG Target Position: 248309.51398
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> LONG Target Position: 274773034.84998
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> LONG Target Position: 5345251.09661
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> LONG Target Position: 81315958.01382
# [DEBUG] TRXUSDT Current position quantity: 0
# [2025-08-10 00:01:00+00:00] - [rebalance] New positions set.
# ------------------------------------------------------------
# [2025-08-13 00:00:00+00:00] - [clear_positions] Clearing all positions. (Current State: REBALANCED)
# [2025-08-13 00:00:00+00:00] - [clear_positions] Clearing: ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT']
# Clear - BTCUSDT: Position: 455, Value: 54330958.50, Price: 119408.7
# Clear - ETHUSDT: Position: 90024, Value: 397589195.52, Price: 4416.48
# Clear - XRPUSDT: Position: 59634875, Value: 191243080.64, Price: 3.2069
# Clear - BCHUSDT: Position: 38701, Value: 22988781.01, Price: 594.01
# Clear - LTCUSDT: Position: 248309, Value: 30427784.86, Price: 122.54
# Clear - ADAUSDT: Position: 274773034, Value: 222044088.78, Price: 0.8081
# Clear - ETCUSDT: Position: 5345251, Value: 122422283.65, Price: 22.903
# Clear - TRXUSDT: Position: 81315958, Value: 28325600.81, Price: 0.34834
# [2025-08-13 00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1065504555.12
# [2025-08-13 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-13 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-13 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-13 00:01:00+00:00] - [rebalance] Strategy results: Long=8, Short=0
# 2025-08-13 00:01:00+00:00 - [rebalance] long_candidates : {'BTCUSDT': 0.09702508541919541, 'ETHUSDT': 0.08957485991049079, 'XRPUSDT': 0.14608306231097348, 'BCHUSDT': 0.1481940773199186, 'LTCUSDT': 0.13308015906655132, 'ADAUSDT': 0.20311866120190722, 'ETCUSDT': 0.09644432405884176, 'TRXUSDT': 0.08647977071212147}
# 2025-08-13 00:01:00+00:00 - [rebalance] short_candidates : {}
# BTCUSDT -> LONG Target Position: 865.94072
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> LONG Target Position: 21597.05182
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> LONG Target Position: 48531561.98701
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> LONG Target Position: 265955.87328
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> LONG Target Position: 1156498.66297
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> LONG Target Position: 267642061.40510
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> LONG Target Position: 4486947.21750
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> LONG Target Position: 264331855.09621
# [DEBUG] TRXUSDT Current position quantity: 0
# [2025-08-13 00:01:00+00:00] - [rebalance] New positions set.
# ------------------------------------------------------------
# [2025-08-16 00:00:00+00:00] - [clear_positions] Clearing all positions. (Current State: REBALANCED)
# [2025-08-16 00:00:00+00:00] - [clear_positions] Clearing: ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'BCHUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT']
# Clear - BTCUSDT: Position: 865, Value: 101430765.00, Price: 117261.0
# Clear - ETHUSDT: Position: 21597, Value: 96738146.28, Price: 4479.24
# Clear - XRPUSDT: Position: 48531561, Value: 148244506.23, Price: 3.0546
# Clear - BCHUSDT: Position: 265955, Value: 156426752.35, Price: 588.17
# Clear - LTCUSDT: Position: 1156498, Value: 137068142.96, Price: 118.52
# Clear - ADAUSDT: Position: 267642061, Value: 250084741.80, Price: 0.9344
# Clear - ETCUSDT: Position: 4486947, Value: 98457078.02, Price: 21.943
# Clear - TRXUSDT: Position: 264331855, Value: 93343507.96, Price: 0.35313
# [2025-08-16 00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1080994664.60
# [2025-08-16 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-16 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-16 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-16 00:01:00+00:00] - [rebalance] Strategy results: Long=0, Short=8
# 2025-08-16 00:01:00+00:00 - [rebalance] long_candidates : {}
# 2025-08-16 00:01:00+00:00 - [rebalance] short_candidates : {'BTCUSDT': -0.13228926692263143, 'ETHUSDT': -0.16168171722115543, 'XRPUSDT': -0.1546051194232212, 'BCHUSDT': -0.07284559351842415, 'LTCUSDT': -0.1421836539026402, 'ADAUSDT': -0.04554844797603247, 'ETCUSDT': -0.15368962169199077, 'TRXUSDT': -0.13715657934390427}
# BTCUSDT -> SHORT Target Position: -1218.14469
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> SHORT Target Position:
00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1089479650.64
# [2025-08-25 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-25 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-25 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-25 00:01:00+00:00] - [rebalance] Strategy results: Long=7, Short=1
# 2025-08-25 00:01:00+00:00 - [rebalance] long_candidates : {'ETHUSDT': 0.19386797579257437, 'XRPUSDT': 0.04671938508885184, 'BCHUSDT': 0.15245276266170793, 'LTCUSDT': 0.16677307621608242, 'ADAUSDT': 0.1845058199138246, 'ETCUSDT': 0.17174050635501192, 'TRXUSDT': 0.05723198216401084}
# 2025-08-25 00:01:00+00:00 - [rebalance] short_candidates : {'BTCUSDT': -0.026708491807936198}
# BTCUSDT -> SHORT Target Position: -254.15295
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> LONG Target Position: 44069.57752
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> LONG Target Position: 16847610.66483
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> LONG Target Position: 279846.47295
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> LONG Target Position: 1520878.51216
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> LONG Target Position: 223150200.37311
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> LONG Target Position: 8030858.56536
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> LONG Target Position: 170763717.77692
# [DEBUG] TRXUSDT Current position quantity: 0
# [2025-08-25 00:01:00+00:00] - [rebalance] New positions set.
# ------------------------------------------------------------
# [2025-08-28 00:00:00+00:00] - [clear_positions] Clearing all positions. (Current State: REBALANCED)
# [2025-08-28 00:00:00+00:00] - [clear_positions] Clearing: ['BTCUSDT', 'ETHUSDT', 'XRPUSDT', 'LTCUSDT', 'ADAUSDT', 'ETCUSDT', 'TRXUSDT', 'BCHUSDT']
# Clear - BTCUSDT: Position: 254, Value: 28372587.40, Price: 111703.1
# Clear - ETHUSDT: Position: 44069, Value: 203065985.79, Price: 4607.91
# Clear - XRPUSDT: Position: 16847610, Value: 50586633.79, Price: 3.0026
# Clear - LTCUSDT: Position: 1520878, Value: 172619653.00, Price: 113.5
# Clear - ADAUSDT: Position: 223150200, Value: 193828263.72, Price: 0.8686
# Clear - ETCUSDT: Position: 8030858, Value: 174839809.52, Price: 21.771
# Clear - TRXUSDT: Position: 170763717, Value: 59769008.59, Price: 0.35001
# Clear - BCHUSDT: Position: 279846, Value: 156238021.80, Price: 558.3
# [2025-08-28 00:00:00+00:00] - [clear_positions] State set to CLEARED. Portfolio value: 1038452438.55
# [2025-08-28 00:01:00+00:00] - [handle_data] Monitoring portfolio: 1.00 minutes since cleared.
# [2025-08-28 00:01:00+00:00] - [rebalance] Setting new positions
# [2025-08-28 00:01:00+00:00] - [rebalance] Fetching history (60 + 1 bars)...
# [2025-08-28 00:01:00+00:00] - [rebalance] Strategy results: Long=8, Short=0
# 2025-08-28 00:01:00+00:00 - [rebalance] long_candidates : {'BTCUSDT': 0.08178782100841842, 'ETHUSDT': 0.0972031148047043, 'XRPUSDT': 0.051158864600310695, 'BCHUSDT': 0.18471612577836583, 'LTCUSDT': 0.10958772071359518, 'ADAUSDT': 0.15949917226451807, 'ETCUSDT': 0.18499098350255733, 'TRXUSDT': 0.13105619732753024}
# 2025-08-28 00:01:00+00:00 - [rebalance] short_candidates : {}
# BTCUSDT -> LONG Target Position: 760.55616
# [DEBUG] BTCUSDT Current position quantity: 0
# ETHUSDT -> LONG Target Position: 21892.48757
# [DEBUG] ETHUSDT Current position quantity: 0
# XRPUSDT -> LONG Target Position: 17691633.76964
# [DEBUG] XRPUSDT Current position quantity: 0
# BCHUSDT -> LONG Target Position: 343569.32135
# [DEBUG] BCHUSDT Current position quantity: 0
# LTCUSDT -> LONG Target Position: 1003020.08642
# [DEBUG] LTCUSDT Current position quantity: 0
# ADAUSDT -> LONG Target Position: 190534689.04228
# [DEBUG] ADAUSDT Current position quantity: 0
# ETCUSDT -> LONG Target Position: 8812726.88165
# [DEBUG] ETCUSDT Current position quantity: 0
# TRXUSDT -> LONG Target Position: 389000992.73832
# [DEBUG] TRXUSDT Current position quantity: 0
# [2025-08-28 00:01:00+00:00] - [rebalance] New positions set.
# ------------------------------------------------------------
#
# --- Backtesting end ---
#
# --- Start of backtest analysis ---
# Final portfolio value: 994722928.34
#
# --- Detailed analysis metrics (API call) ---
# Cumulative Return (API): -0.00528 (-0.528%)
# Daily Sharpe Ratio (API): 0.009
# Monthly Sharpe Ratio (API): 0.050
# Annual Sharpe Ratio (API): 0.000
# Maximum drop (API): -0.16008 (-16.008%)
#
# --- Detailed Analysis Indicator (Empyrical) ---
# Sharp Ratio (Empyrical, annualized): 0.000
# Maximum drop (Empyrical): -0.16008 (-16.008%)
#
# --- End of backtest analysis ---
# INFO: Backtest engine run completed successfully. Duration: 0:00:35.942376
# INFO: Starting report generation...
#   - Saving HTML report
# INFO: HTML report generated successfully. Duration: 0:00:21.364132
# [2025-09-18 09:54:36+0000] Backtest script execution completed successfully. Total time: 0:01:10.293600
#
# --- Execution Output (stdout) ---
# - strategy: simple_volatility.py
