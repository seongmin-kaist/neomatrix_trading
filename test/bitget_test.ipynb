# %%
import pandas as pd
import numpy as np
import ccxt
import time
from datetime import datetime, timedelta, timezone
import requests

days_to_fetch=30
exchange = ccxt.bitget()
# 1 minute timeframe
timeframe = '1m'
# Calculate the starting timestamp
since = exchange.parse8601((datetime.utcnow() - timedelta(days=days_to_fetch)).isoformat())
# Out:
# /var/folders/3r/df6gd3t56pq6t10_rqr2h7pr0000gn/T/ipykernel_99099/3539721314.py:13: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   since = exchange.parse8601((datetime.utcnow() - timedelta(days=days_to_fetch)).isoformat())

# %%
since
# Out:
# 1756105513125

# %%
import ccxt
import pandas as pd
from datetime import datetime, timedelta
import time

# --- Configuration ---
# 데이터를 가져올 심볼 목록
SYMBOLS = ["BTC/USDT", "ETH/USDT", "BGB/USDT"]
# 최근 몇 일간의 데이터를 가져올지 설정
DAYS_TO_FETCH = 5

def create_kline_dataframe_with_ccxt(symbol, days):
    """
    ccxt를 사용하여 OHLCV와 Taker 매수 거래량을 포함하는 DataFrame을 생성합니다.
    """
    # ccxt Bitget 인스턴스 생성
    exchange = ccxt.bitget()

    print(f"\nFetching last {days} days of OHLCV data for {symbol}...")
    
    # ccxt는 타임스탬프를 밀리초 단위로 사용합니다.
    since = exchange.parse8601((datetime.utcnow() - timedelta(days=days)).isoformat())
    
    try:
        # 1일봉 데이터 가져오기
        ohlcv = exchange.fetch_ohlcv(symbol, '1d', since, limit=days)
        if not ohlcv:
            print(f"No kline data received for {symbol}.")
            return f"Could not create DataFrame for {symbol}."

        kline_df = pd.DataFrame(ohlcv, columns=['timestamp_ms', 'open', 'high', 'low', 'close', 'volume'])
        kline_df['timestamp'] = pd.to_datetime(kline_df['timestamp_ms'], unit='ms')
        
        print(f"✅ Successfully fetched OHLCV data for {symbol}.")

    except ccxt.Error as e:
        print(f"An error occurred fetching klines for {symbol}: {e}")
        return f"Could not create DataFrame for {symbol}."

    taker_volumes = []
    print(f"\nCalculating Taker Buy Volume for each day for {symbol}. This may take a moment...")

    # 각 일봉에 대해 Taker 매수 거래량 계산
    for index, row in kline_df.iterrows():
        start_ts = int(row['timestamp_ms'])
        end_ts = start_ts + timedelta(days=1).total_seconds() * 1000
        
        print(f"Processing data for {row['timestamp'].strftime('%Y-%m-%d')}...")
        
        all_trades_for_day_period = []
        fetch_since = start_ts
        
        # 해당 날짜의 모든 거래 내역을 가져오기 위한 루프
        while True:
            try:
                # API 속도 제한을 위해 약간의 딜레이 추가
                time.sleep(exchange.rateLimit / 1000)
                
                trades = exchange.fetch_trades(symbol, since=fetch_since, limit=1000)
                
                if not trades:
                    # 더 이상 가져올 거래 내역이 없으면 종료
                    break

                all_trades_for_day_period.extend(trades)
                
                last_trade_ts = trades[-1]['timestamp']
                
                # 가져온 마지막 거래가 해당 날짜의 범위를 넘어서면 더 이상 가져올 필요 없음
                if last_trade_ts >= end_ts:
                    break
                
                # 다음 fetch를 위해 마지막 거래의 타임스탬프 + 1ms로 설정
                fetch_since = last_trade_ts + 1

            except ccxt.Error as e:
                print(f"An error occurred fetching trades for {symbol}: {e}")
                break # 에러 발생 시 루프 종료
        
        # 가져온 모든 거래 내역 중에서 해당 날짜에 해당하는 Taker 매수 거래만 필터링하여 합산
        taker_buy_trades = [
            trade.get('cost', 0) for trade in all_trades_for_day_period 
            if start_ts <= trade['timestamp'] < end_ts and
               trade.get('side') == 'buy' and 
               trade.get('takerOrMaker') == 'taker' and
               trade.get('cost') is not None
        ]
        total_taker_buy_volume = sum(taker_buy_trades)
        taker_volumes.append(total_taker_buy_volume)

    # 계산된 거래량을 DataFrame에 새로운 컬럼으로 추가
    kline_df['takerBuyQuoteVol'] = taker_volumes
    
    # 최종 DataFrame 구조 정리
    final_df = kline_df[['timestamp', 'open', 'high', 'low', 'close', 'volume', 'takerBuyQuoteVol']]
    final_df = final_df.set_index('timestamp')
    
    print(f"\n✅ All data processed successfully for {symbol}!")
    return final_df

if __name__ == "__main__":
    for symbol in SYMBOLS:
        # Bitget API 심볼 형식은 'BTC/USDT'이지만, 파일이나 출력에서는 다른 형식을 사용할 수 있습니다.
        print(f"\n{'='*50}")
        print(f"Processing Symbol: {symbol}")
        print(f"{'='*50}")
        
        final_dataframe = create_kline_dataframe_with_ccxt(symbol, DAYS_TO_FETCH)
        
        print(f"\n--- Final Kline DataFrame for {symbol} ---")
        print(final_dataframe)
        print(f"\n--- End of data for {symbol} ---\n")
# Out:
# ==================================================
# Processing Symbol: BTC/USDT
# ==================================================
#
# Fetching last 5 days of OHLCV data for BTC/USDT...
# /var/folders/3r/df6gd3t56pq6t10_rqr2h7pr0000gn/T/ipykernel_99099/2116860941.py:22: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   since = exchange.parse8601((datetime.utcnow() - timedelta(days=days)).isoformat())
# ✅ Successfully fetched OHLCV data for BTC/USDT.
#
# Calculating Taker Buy Volume for each day for BTC/USDT. This may take a moment...
# Processing data for 2025-09-20...
# Processing data for 2025-09-21...
# Processing data for 2025-09-22...
# Processing data for 2025-09-23...
# Processing data for 2025-09-24...
#
# ✅ All data processed successfully for BTC/USDT!
#
# --- Final Kline DataFrame for BTC/USDT ---
#                  open       high        low      close        volume  \
# timestamp
# 2025-09-20  115626.95  116124.23  115413.00  115676.33   2543.299793
# 2025-09-21  115676.33  115812.57  115180.68  115244.87   2936.684552
# 2025-09-22  115244.87  115379.78  111832.69  112655.18  12886.394256
# 2025-09-23  112655.18  113300.00  111468.09  112009.50   5973.597286
# 2025-09-24  112009.50  112919.99  111051.88  112909.10   3325.345164
#
#             takerBuyQuoteVol
# timestamp
# 2025-09-20                 0
# 2025-09-21                 0
# 2025-09-22                 0
# 2025-09-23                 0
# 2025-09-24                 0
#
# --- End of data for BTC/USDT ---
#
#
# ==================================================
# Processing Symbol: ETH/USDT
# ==================================================
#
# Fetching last 5 days of OHLCV data for ETH/USDT...
# /var/folders/3r/df6gd3t56pq6t10_rqr2h7pr0000gn/T/ipykernel_99099/2116860941.py:22: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   since = exchange.parse8601((datetime.utcnow() - timedelta(days=days)).isoformat())
# ✅ Successfully fetched OHLCV data for ETH/USDT.
#
# Calculating Taker Buy Volume for each day for ETH/USDT. This may take a moment...
# Processing data for 2025-09-20...
# Processing data for 2025-09-21...
# Processing data for 2025-09-22...
# Processing data for 2025-09-23...
# Processing data for 2025-09-24...
#
# ✅ All data processed successfully for ETH/USDT!
#
# --- Final Kline DataFrame for ETH/USDT ---
#                open     high      low    close         volume  \
# timestamp
# 2025-09-20  4469.30  4509.00  4454.49  4480.34   82100.115786
# 2025-09-21  4480.34  4498.41  4443.07  4445.09   88707.135251
# 2025-09-22  4445.09  4456.40  4072.91  4199.09  370204.390752
# 2025-09-23  4199.09  4229.32  4114.71  4164.35  203073.885717
# 2025-09-24  4164.35  4194.91  4074.54  4175.76   90247.545551
#
#             takerBuyQuoteVol
# timestamp
# 2025-09-20                 0
# 2025-09-21                 0
# 2025-09-22                 0
# 2025-09-23                 0
# 2025-09-24                 0
#
# --- End of data for ETH/USDT ---
#
#
# ==================================================
# Processing Symbol: BGB/USDT
# ==================================================
#
# Fetching last 5 days of OHLCV data for BGB/USDT...
# /var/folders/3r/df6gd3t56pq6t10_rqr2h7pr0000gn/T/ipykernel_99099/2116860941.py:22: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   since = exchange.parse8601((datetime.utcnow() - timedelta(days=days)).isoformat())
# ✅ Successfully fetched OHLCV data for BGB/USDT.
#
# Calculating Taker Buy Volume for each day for BGB/USDT. This may take a moment...
# Processing data for 2025-09-20...
# Processing data for 2025-09-21...
# Processing data for 2025-09-22...
# Processing data for 2025-09-23...
# Processing data for 2025-09-24...
#
# ✅ All data processed successfully for BGB/USDT!
#
# --- Final Kline DataFrame for BGB/USDT ---
#              open   high    low  close        volume  takerBuyQuoteVol
# timestamp
# 2025-09-20  5.113  5.332  5.113  5.291  3.852009e+07                 0
# 2025-09-21  5.291  5.395  5.209  5.238  4.732723e+07                 0
# 2025-09-22  5.238  5.240  4.929  5.169  1.023712e+08                 0
# 2025-09-23  5.169  5.277  5.086  5.248  5.275705e+07                 0
# 2025-09-24  5.248  5.303  5.159  5.253  3.471332e+07                 0
#
# --- End of data for BGB/USDT ---

# %%
final_dataframe
# Out:
#              open   high    low  close        volume  takerBuyQuoteVol
# timestamp
# 2025-09-20  5.113  5.332  5.113  5.291  3.852009e+07                 0
# 2025-09-21  5.291  5.395  5.209  5.238  4.732723e+07                 0
# 2025-09-22  5.238  5.240  4.929  5.169  1.023712e+08                 0
# 2025-09-23  5.169  5.277  5.086  5.248  5.275705e+07                 0
# 2025-09-24  5.248  5.303  5.159  5.252  3.451580e+07                 0

# %%
import requests
import json

url = "https://crypto.fin.cloud.ainode.ai/a71eaf04-802f-40be-93c2-5bee2548f4db/get/info/coin"
response = requests.get(url)
data = response.json()

symbols = []
for item in data['data']:
    symbols.append(item['coin_nm'] + '/USDT')

# %%
url = "https://api.bitget.com/api/v2/mix/market/history-candles?symbol=BTCUSDT&granularity=1D&limit=200&productType=usdt-futures"
response = requests.get(url)
data = response.json()
data
# Out:
# {'code': '00000',
#  'msg': 'success',
#  'requestTime': 1758706597523,
#  'data': [['1750867200000',
#    '106982.1',
#    '108222.2',
#    '106520',
#    '107256.1',
#    '113240',
#    '111434.8',
#    '112830.1',
#    '45473.49890488',
#    '5119098552.783848268']]}

# %%
pd.DataFrame(data)
# Out:
#      code      msg    requestTime  \
# 0   00000  success  1758706597523
# 1   00000  success  1758706597523
# 2   00000  success  1758706597523
# 3   00000  success  1758706597523
# 4   00000  success  1758706597523
# ..    ...      ...            ...
# 85  00000  success  1758706597523
# 86  00000  success  1758706597523
# 87  00000  success  1758706597523
# 88  00000  success  1758706597523
# 89  00000  success  1758706597523
#
#                                                  data
# 0   [1750867200000, 106982.1, 108222.2, 106520, 10...
# 1   [1750953600000, 107256.1, 107960.7, 106317.5, ...
# 2   [1751040000000, 107251.8, 107672.1, 106393.4, ...
# 3   [1751126400000, 107406.7, 108480, 107095.8, 10...
# 4   [1751212800000, 107700.8, 108738.4, 106691.7, ...
# ..                                                ...
# 85  [1758211200000, 117526.5, 117855.5, 115423, 11...
# 86  [1758297600000, 115825.9, 116084.1, 115059.3, ...
# 87  [1758384000000, 115929.9, 116026.8, 115271.9, ...
# 88  [1758470400000, 115471.7, 115622.9, 111549.3, ...
# 89  [1758556800000, 112772.7, 113240, 111434.8, 11...
#
# [90 rows x 4 columns]

# %%
curl "https://api.bitget.com/api/v2/mix/market/history-candles?symbol=BTCUSDT&granularity=1W&limit=200&productType=usdt-futures"

# %%
symbols
# Out:
# ['BTC/USDT',
#  'USDT/USDT',
#  'ETH/USDT',
#  'IOST/USDT',
#  'LTC/USDT',
#  'BCH/USDT',
#  'QTUM/USDT',
#  'ETC/USDT',
#  'SOLS/USDT',
#  'BEBE/USDT',
#  'CSAS/USDT',
#  'COQ/USDT',
#  'MICE/USDT',
#  'COM/USDT',
#  'ZERO/USDT',
#  'GRAPE/USDT',
#  'BTCMEME/USDT',
#  'UP/USDT',
#  'MMSS/USDT',
#  'NFP/USDT',
#  'SNEK/USDT',
#  'ANALOS/USDT',
#  'SILLY/USDT',
#  'AIMX/USDT',
#  'ARTY/USDT',
#  '3ULL/USDT',
#  'PEPECOIN/USDT',
#  '1CAT/USDT',
#  'SCPT/USDT',
#  'MOBILE/USDT',
#  'SIX/USDT',
#  'ZKF/USDT',
#  'STRK/USDT',
#  'ELA/USDT',
#  'BRCT/USDT',
#  'FNSA/USDT',
#  'OORT/USDT',
#  'PROPS/USDT',
#  'XPET/USDT',
#  'WOOF/USDT',
#  'DUSD/USDT',
#  'RDNT/USDT',
#  'OX/USDT',
#  'GRAIL/USDT',
#  'AGIX/USDT',
#  'IMGNAI/USDT',
#  'ORAI/USDT',
#  'PSI/USDT',
#  'AI/USDT',
#  'ALI/USDT',
#  'ARBINU/USDT',
#  'SOLO/USDT',
#  'APP/USDT',
#  'MMIT/USDT',
#  'PKEY/USDT',
#  'MCH/USDT',
#  'RABBIT/USDT',
#  'ISLM/USDT',
#  'ORDS/USDT',
#  'CORE/USDT',
#  'XAI/USDT',
#  'ZYB/USDT',
#  '$AI/USDT',
#  'MDAO/USDT',
#  'STRIKE/USDT',
#  'DPX/USDT',
#  'PLS/USDT',
#  'CAI/USDT',
#  'FLR/USDT',
#  'BFR/USDT',
#  'JONES/USDT',
#  'THENA/USDT',
#  'BTCS/USDT',
#  'DIMO/USDT',
#  'WAGMIGAMES/USDT',
#  'BABYELON/USDT',
#  'AVAV/USDT',
#  'UPC/USDT',
#  'EVO/USDT',
#  'BLUR/USDT',
#  'DOME/USDT',
#  'CHESS/USDT',
#  'LM/USDT',
#  'THALES/USDT',
#  'VSC/USDT',
#  'CTR/USDT',
#  'FDUSD/USDT',
#  'HAMI/USDT',
#  'VELA/USDT',
#  'JPEG/USDT',
#  'IGU/USDT',
#  'RARE/USDT',
#  'BBO/USDT',
#  'ZUZALU/USDT',
#  'BABYBONK/USDT',
#  'AVA/USDT',
#  'ALT/USDT',
#  'OPUL/USDT',
#  'CLORE/USDT',
#  'ZKB/USDT',
#  'RON/USDT',
#  'TRU/USDT',
#  'TROLL/USDT',
#  'SUDO/USDT',
#  'SMILEY/USDT',
#  'ZZ/USDT',
#  'PONKE/USDT',
#  'RDPX/USDT',
#  'MANTA/USDT',
#  'VSTA/USDT',
#  'MDT/USDT',
#  'TROVE/USDT',
#  'VELO/USDT',
#  'MUTE/USDT',
#  'BIZA/USDT',
#  'GTAI/USDT',
#  'ONDO/USDT',
#  'WIF/USDT',
#  '$ALT/USDT',
#  'RDEX/USDT',
#  'BABYDRAGON/USDT',
#  'TSUGT/USDT',
#  'COCOS/USDT',
#  'OAX/USDT',
#  'STORE/USDT',
#  'FON/USDT',
#  'AMU/USDT',
#  'LVL/USDT',
#  'DUEL/USDT',
#  'LQTY/USDT',
#  'SAROS/USDT',
#  'WOM/USDT',
#  'GMD/USDT',
#  'VAI/USDT',
#  'SONNE/USDT',
#  'ORNJ/USDT',
#  'JUP/USDT',
#  'GROKCEO/USDT',
#  'DMAIL/USDT',
#  'DEFI/USDT',
#  'ZETA/USDT',
#  'VMINT/USDT',
#  '$STC/USDT',
#  'GUAC/USDT',
#  'LYRA/USDT',
#  'COLLAB/USDT',
#  'OPX/USDT',
#  'KWENTA/USDT',
#  'SMART/USDT',
#  'HALO/USDT',
#  'COREUM/USDT',
#  'FLM/USDT',
#  'ASM/USDT',
#  'QLC/USDT',
#  'PAW/USDT',
#  'LEASH/USDT',
#  'DGI/USDT',
#  'JAN/USDT',
#  'GRPH/USDT',
#  'PORK/USDT',
#  'CAMLY/USDT',
#  'VR/USDT',
#  'WEN/USDT',
#  'TRAC/USDT',
#  'FIRE/USDT',
#  'DIGI/USDT',
#  'GAS/USDT',
#  'VELO1/USDT',
#  'NOM/USDT',
#  'PRIME1/USDT',
#  'ELON/USDT',
#  'PEPES/USDT',
#  'SPOOL/USDT',
#  'KAKI/USDT',
#  'MCHC/USDT',
#  'VXL/USDT',
#  'MOVER/USDT',
#  'STX/USDT',
#  'OPTIMUS/USDT',
#  'ASTR/USDT',
#  'ARBK/USDT',
#  'GLTR/USDT',
#  'GPT/USDT',
#  'AURA1/USDT',
#  'TEM/USDT',
#  'GFAL/USDT',
#  'ALIEN/USDT',
#  'IPOR/USDT',
#  'GCAKE/USDT',
#  'SUIBG/USDT',
#  'BPRIVA/USDT',
#  'RJV/USDT',
#  'JASMY/USDT',
#  'DZOO/USDT',
#  'GENE/USDT',
#  'CAPS/USDT',
#  'TONCOIN/USDT',
#  'GDX/USDT',
#  'LIKE/USDT',
#  'LSD/USDT',
#  'WND/USDT',
#  'ARB/USDT',
#  'BLOK/USDT',
#  'DRACE/USDT',
#  'ELMON/USDT',
#  'FOLD/USDT',
#  'OATH/USDT',
#  'REELT/USDT',
#  'STABLZ/USDT',
#  'ARBETF/USDT',
#  'CVX/USDT',
#  'FAST/USDT',
#  'SPELL/USDT',
#  'SERP/USDT',
#  'TOKE/USDT',
#  'ID/USDT',
#  'SIN/USDT',
#  'CSIX/USDT',
#  'SLND/USDT',
#  'PRY/USDT',
#  'RIN/USDT',
#  'DEG/USDT',
#  'VIDT/USDT',
#  'COTI/USDT',
#  'RNDR/USDT',
#  'FXS/USDT',
#  'SOLR/USDT',
#  'FIO/USDT',
#  'MONI/USDT',
#  'CEEK/USDT',
#  'DENT/USDT',
#  'LIFE/USDT',
#  'FLOKI/USDT',
#  'FREE/USDT',
#  'KIN/USDT',
#  'FEVR/USDT',
#  'MAN/USDT',
#  'EGLD/USDT',
#  'NEAR/USDT',
#  'SOS/USDT',
#  'CST/USDT',
#  'FOR/USDT',
#  'GOG/USDT',
#  'SSS/USDT',
#  'AR/USDT',
#  'KSM/USDT',
#  'PIT/USDT',
#  'HEX/USDT',
#  'RLY/USDT',
#  'JADE/USDT',
#  'ORKL/USDT',
#  'GODZ/USDT',
#  'PEOPLE/USDT',
#  'ONIT/USDT',
#  'LOOKS/USDT',
#  'CHARGE/USDT',
#  'SHILL/USDT',
#  'ACA/USDT',
#  'METIS/USDT',
#  'ALPHA/USDT',
#  'QRDO/USDT',
#  'BABYDOGE/USDT',
#  'JUV/USDT',
#  'KLAY/USDT',
#  'AUDIO/USDT',
#  'C98/USDT',
#  'TLOS/USDT',
#  'ILV/USDT',
#  'WEMIX/USDT',
#  'JUSTICE/USDT',
#  'RSS3/USDT',
#  'ANT/USDT',
#  'ARPA/USDT',
#  'FTT/USDT',
#  'DUSK/USDT',
#  'DAR/USDT',
#  'WOO/USDT',
#  'REAL/USDT',
#  'OSMO/USDT',
#  'TORN/USDT',
#  'FTM/USDT',
#  'X2Y2/USDT',
#  'LUNA/USDT',
#  'USDSP/USDT',
#  'WIN/USDT',
#  'SUN/USDT',
#  'SUPER/USDT',
#  'KP3R/USDT',
#  'TAP/USDT',
#  'NEO/USDT',
#  'PSTAKE/USDT',
#  'DSP/USDT',
#  'TFBX/USDT',
#  'PERP/USDT',
#  'WAVES/USDT',
#  'POKT/USDT',
#  'FTSY/USDT',
#  'KNOT/USDT',
#  'XYM/USDT',
#  'ZBC/USDT',
#  'BASETOKEN/USDT',
#  'OMI/USDT',
#  'BEFI/USDT',
#  'IVPAY/USDT',
#  'NAVX/USDT',
#  'NAVI/USDT',
#  'DYM/USDT',
#  'MAVIA/USDT',
#  'DWARS/USDT',
#  'OORTTOKEN/USDT',
#  'AINN/USDT',
#  'OLAS/USDT',
#  'HTX/USDT',
#  'REACH/USDT',
#  'NESS/USDT',
#  'BBL/USDT',
#  'ML/USDT',
#  'ASTO/USDT',
#  'VEXT/USDT',
#  'SORA/USDT',
#  'PIXEL/USDT',
#  'ANIM/USDT',
#  'NUUM/USDT',
#  'PORTAL/USDT',
#  'SERSH/USDT',
#  'PZP/USDT',
#  'BEANS/USDT',
#  'AKU/USDT',
#  'OWL/USDT',
#  'NADA/USDT',
#  'PANDORA/USDT',
#  'ICE/USDT',
#  'MV/USDT',
#  'SLN/USDT',
#  'HELLO/USDT',
#  'TAO/USDT',
#  'DEGEN/USDT',
#  'CGPT/USDT',
#  'ZZZ/USDT',
#  'PENDLE/USDT',
#  'PYAY/USDT',
#  'RDNTOLD/USDT',
#  'COMAI/USDT',
#  'ORBK/USDT',
#  'DEVVE/USDT',
#  'ALVA/USDT',
#  'HGPT/USDT',
#  'DEPD/USDT',
#  'VIA/USDT',
#  'FMB/USDT',
#  'MAPO/USDT',
#  'PLAY/USDT',
#  '$GPT/USDT',
#  'LSDETF/USDT',
#  'TRIAS/USDT',
#  'AIDOGE/USDT',
#  'STETH/USDT',
#  'WOJAK/USDT',
#  'PEPE/USDT',
#  'TOMI/USDT',
#  'MEMEETF/USDT',
#  'KAS/USDT',
#  'SHIBAI/USDT',
#  'MVL/USDT',
#  'CREO/USDT',
#  'LAKE/USDT',
#  'ALITA/USDT',
#  'PENG/USDT',
#  'ZBU/USDT',
#  'KLV/USDT',
#  'CHAD/USDT',
#  'QUARK/USDT',
#  'DINO/USDT',
#  'SCA/USDT',
#  'LZBG/USDT',
#  'XPLA/USDT',
#  'REKT/USDT',
#  'STONKS/USDT',
#  'PLEB/USDT',
#  'PEPEGPT/USDT',
#  'XNO/USDT',
#  'PCI/USDT',
#  'PMG/USDT',
#  'ETHFI/USDT',
#  'MC/USDT',
#  'NETZ/USDT',
#  'BENDOG/USDT',
#  'SYLO/USDT',
#  'BRETT/USDT',
#  'EDU/USDT',
#  'RMV/USDT',
#  'AICODE/USDT',
#  'AEVO/USDT',
#  'OGGY/USDT',
#  'XCHNG/USDT',
#  'SUI/USDT',
#  'SYNC/USDT',
#  'POGAI/USDT',
#  'HAHA/USDT',
#  'WSB/USDT',
#  'MONG/USDT',
#  'CLIPS/USDT',
#  'TURBO/USDT',
#  'DIS/USDT',
#  'FMBC/USDT',
#  'BOME/USDT',
#  'PUSH/USDT',
#  'DMR/USDT',
#  'GOMD/USDT',
#  'NEVER/USDT',
#  'POOH/USDT',
#  'RIBBIT/USDT',
#  'GEC/USDT',
#  'PEEPO/USDT',
#  'KUB/USDT',
#  'CAL/USDT',
#  'SHIDO/USDT',
#  'BIP1/USDT',
#  'IQ50/USDT',
#  'LITT/USDT',
#  'ORDI/USDT',
#  'SPONGE/USDT',
#  'NALS/USDT',
#  'MEME/USDT',
#  'ZK/USDT',
#  'VOYA/USDT',
#  'SLERF/USDT',
#  'PIKA/USDT',
#  'WSG/USDT',
#  'LYX/USDT',
#  'TOAD/USDT',
#  'ANDY/USDT',
#  'VMPX/USDT',
#  'PEPE1/USDT',
#  'LADYS/USDT',
#  'DUKO/USDT',
#  'CAPO/USDT',
#  '$POGAI/USDT',
#  'POOLX/USDT',
#  'SNAP/USDT',
#  'PIZA/USDT',
#  'PROPC/USDT',
#  'PIP/USDT',
#  'TENET/USDT',
#  'EGO/USDT',
#  'MSTR/USDT',
#  'DCB/USDT',
#  'DFC/USDT',
#  'ATOMARC/USDT',
#  'JENSEN/USDT',
#  'OMNI/USDT',
#  'AAI/USDT',
#  'BHAT/USDT',
#  'RFD/USDT',
#  'DONS/USDT',
#  'INFRA/USDT',
#  'LAI/USDT',
#  'BEN/USDT',
#  'KATA/USDT',
#  '3TH/USDT',
#  'EZSWAP/USDT',
#  'AREA/USDT',
#  'AIBB/USDT',
#  'SEI/USDT',
#  'INU/USDT',
#  'AWT/USDT',
#  'SXS/USDT',
#  'SCLP/USDT',
#  'HAM/USDT',
#  'GPTG/USDT',
#  'COMBO/USDT',
#  'GUI/USDT',
#  'FERC/USDT',
#  'TREEB/USDT',
#  'BLUE/USDT',
#  'OMN/USDT',
#  'FAVOR/USDT',
#  'UNLEASH/USDT',
#  'GMT/USDT',
#  'ALPHA1/USDT',
#  'MAGIC/USDT',
#  'RBW/USDT',
#  'SD/USDT',
#  'WSM/USDT',
#  'EFI/USDT',
#  'MTC/USDT',
#  'XDC/USDT',
#  'GQ/USDT',
#  'APE/USDT',
#  'MAV/USDT',
#  'ABBC/USDT',
#  'ORB/USDT',
#  'GINOA/USDT',
#  'TYPE/USDT',
#  'KYVE/USDT',
#  'PEPE2/USDT',
#  'BMTC/USDT',
#  'BOT/USDT',
#  'LBR/USDT',
#  'RBN/USDT',
#  'AGB/USDT',
#  'JUNO/USDT',
#  'WOOO/USDT',
#  'NPT/USDT',
#  'STG/USDT',
#  'VMPXERC20/USDT',
#  'RUNE/USDT',
#  'L/USDT',
#  'RAY/USDT',
#  'BSW/USDT',
#  'DODO/USDT',
#  'ORCA/USDT',
#  'BNX/USDT',
#  'COW/USDT',
#  'CULT/USDT',
#  'CUSD/USDT',
#  'KYOKO/USDT',
#  'ELFI/USDT',
#  'POLYDOGE/USDT',
#  'AURORA/USDT',
#  'NEXO/USDT',
#  'AMP/USDT',
#  'CEL/USDT',
#  'LPT/USDT',
#  'PAXG/USDT',
#  'VLX/USDT',
#  'VGX/USDT',
#  'TEL/USDT',
#  'TRYB/USDT',
#  'BTT/USDT',
#  'GLM/USDT',
#  'VISION/USDT',
#  'NYM/USDT',
#  'MMETA/USDT',
#  'VT/USDT',
#  'VRA/USDT',
#  'GST/USDT',
#  'FLUX/USDT',
#  'ROSE/USDT',
#  'ELT/USDT',
#  'HNT/USDT',
#  'BEND/USDT',
#  'MOONEY/USDT',
#  'FITFI/USDT',
#  'NXD/USDT',
#  'IZI/USDT',
#  'IUSD/USDT',
#  'STRM/USDT',
#  'BREED/USDT',
#  'PPAD/USDT',
#  'GAL/USDT',
#  'TUSD/USDT',
#  'ELF/USDT',
#  'ZIL/USDT',
#  'BAT/USDT',
#  'CHAT/USDT',
#  'DAI/USDT',
#  'STI/USDT',
#  'WAXP/USDT',
#  'LUNR/USDT',
#  'PRIME/USDT',
#  'EWAR/USDT',
#  'KUNCI/USDT',
#  'BRWL/USDT',
#  'BRZ/USDT',
#  'GALFAN/USDT',
#  'MULTI/USDT',
#  'OMC/USDT',
#  'USDD/USDT',
#  'WIRTUAL/USDT',
#  'KDA/USDT',
#  'SXP/USDT',
#  'LUNC/USDT',
#  'USTC/USDT',
#  'CEUR/USDT',
#  'SNT/USDT',
#  'LINK/USDT',
#  'ZRX/USDT',
#  'LRC/USDT',
#  'POLY/USDT',
#  'BSV/USDT',
#  'OMG/USDT',
#  'OP/USDT',
#  'EVMOS/USDT',
#  'REVO/USDT',
#  'SHIT/USDT',
#  'FET/USDT',
#  'SYS/USDT',
#  'HOP/USDT',
#  'VOLT/USDT',
#  'MOVEZ/USDT',
#  'AFK/USDT',
#  'GTC/USDT',
#  'LOOM/USDT',
#  'BLZ/USDT',
#  'TRX/USDT',
#  'KAI/USDT',
#  'CUBENETWORK/USDT',
#  'FOTA/USDT',
#  'WLKN/USDT',
#  'FORT/USDT',
#  'BOO/USDT',
#  'JOE/USDT',
#  'QUICK/USDT',
#  'SPIRIT/USDT',
#  'CELR/USDT',
#  'MANA/USDT',
#  'ENJ/USDT',
#  'XRP/USDT',
#  'EOS/USDT',
#  'USDC/USDT',
#  'BCHA/USDT',
#  'UNI/USDT',
#  'SUSHI/USDT',
#  'COMP/USDT',
#  'AAVE/USDT',
#  'YFI/USDT',
#  'DOGE/USDT',
#  'CHZ/USDT',
#  'HOT/USDT',
#  'LINA/USDT',
#  'BNB/USDT',
#  'MATIC/USDT',
#  '1INCH/USDT',
#  'SNX/USDT',
#  'MKR/USDT',
#  'UMA/USDT',
#  'REN/USDT',
#  'BAL/USDT',
#  'BNT/USDT',
#  'NMR/USDT',
#  'CRV/USDT',
#  'YFII/USDT',
#  'WNXM/USDT',
#  'ALE/USDT',
#  'AD/USDT',
#  'RUB/USDT',
#  'UAH/USDT',
#  '0X0/USDT',
#  'PLANET/USDT',
#  'FAVR/USDT',
#  'SHIB2/USDT',
#  'DOGE2/USDT',
#  'BABYDOGE2/USDT',
#  'PAYU/USDT',
#  'NOVA/USDT',
#  'ARKM/USDT',
#  'EML/USDT',
#  'HOPPY/USDT',
#  'SALD/USDT',
#  'AZIT/USDT',
#  'XUI/USDT',
#  'PC/USDT',
#  'BITCOIN/USDT',
#  'UNIBOT/USDT',
#  'WAGIEBOT/USDT',
#  'BRIDGE/USDT',
#  'MOG/USDT',
#  'WLD/USDT',
#  'OMNIA/USDT',
#  'SOPH/USDT',
#  'GMMT/USDT',
#  'ESPR/USDT',
#  'STIK/USDT',
#  'API3/USDT',
#  'HBAR/USDT',
#  'SKL/USDT',
#  'XXX/USDT',
#  'MX/USDT',
#  'SML/USDT',
#  'BITCOINBSC/USDT',
#  'X/USDT',
#  'GRIMACE/USDT',
#  'TEST/USDT',
#  'UBXS/USDT',
#  'TROSS/USDT',
#  'SDEX/USDT',
#  'BROCK/USDT',
#  'MMVG/USDT',
#  'AIMBOT/USDT',
#  'SOLANA/USDT',
#  'FTN/USDT',
#  'CORETOKEN/USDT',
#  'KAT/USDT',
#  'TET/USDT',
#  'LAB/USDT',
#  'XRP8/USDT',
#  'BAD/USDT',
#  'CYBER/USDT',
#  'AITECH/USDT',
#  'GOMINING/USDT',
#  'PEPECOMMUNITY/USDT',
#  'MNTC/USDT',
#  'WALV/USDT',
#  'PEPE2COMMUNITY/USDT',
#  'NVIR/USDT',
#  'SHIA/USDT',
#  'MARO/USDT',
#  'ACN/USDT',
#  'MCADE/USDT',
#  'SHEPE/USDT',
#  'YAMA/USDT',
#  'DORKL/USDT',
#  'WITCH/USDT',
#  'CSPR/USDT',
#  'EUL/USDT',
#  'CMP/USDT',
#  'EVA/USDT',
#  'LUFFY/USDT',
#  'MAX/USDT',
#  'LAT/USDT',
#  'SMURFCAT/USDT',
#  'OBX/USDT',
#  'CRETA/USDT',
#  'EUROC/USDT',
#  'MIT/USDT',
#  'SFP/USDT',
#  'CERE/USDT',
#  'TIP/USDT',
#  'BANANA/USDT',
#  'CBK/USDT',
#  'OGV/USDT',
#  'ROOBEE/USDT',
#  'FINE/USDT',
#  'XIDR/USDT',
#  'APX/USDT',
#  'OLE/USDT',
#  'PYUSD/USDT',
#  'GLMR/USDT',
#  'XOR/USDT',
#  'IP3/USDT',
#  'MNT/USDT',
#  'IOTX/USDT',
#  'WWY/USDT',
#  'JNS/USDT',
#  'MINA/USDT',
#  'FIU/USDT',
#  'SLG/USDT',
#  'XCAD/USDT',
#  'DAO/USDT',
#  'XETA/USDT',
#  'WRT/USDT',
#  'ORT/USDT',
#  'ALPACA/USDT',
#  'WOMBAT/USDT',
#  'TUP/USDT',
#  'IXT/USDT',
#  'BITCI/USDT',
#  'ZIG/USDT',
#  'MHUNT/USDT',
#  'TFUEL/USDT',
#  'HUB/USDT',
#  'AURA/USDT',
#  'REI/USDT',
#  'MCRT/USDT',
#  'GVR/USDT',
#  'STC/USDT',
#  'PORTO/USDT',
#  'LAZIO/USDT',
#  'ACM/USDT',
#  'BAR/USDT',
#  'SANTOS/USDT',
#  'CITY/USDT',
#  'POR/USDT',
#  'ARG/USDT',
#  'CANTO/USDT',
#  'INTER/USDT',
#  'LOVELY/USDT',
#  'NAP/USDT',
#  'MENGO/USDT',
#  'TRA/USDT',
#  'AFC/USDT',
#  'CRT/USDT',
#  'PLEX/USDT',
#  'XMON/USDT',
#  'TSUKA/USDT',
#  'SKEB/USDT',
#  'SWEAT/USDT',
#  'LING/USDT',
#  'AMPL/USDT',
#  'ETHW/USDT',
#  'AKRO/USDT',
#  'APM/USDT',
#  'ABT/USDT',
#  'AERGO/USDT',
#  'ALPINE/USDT',
#  'AUCTION/USDT',
#  'ACH/USDT',
#  'BADGER/USDT',
#  'BICO/USDT',
#  'BTCST/USDT',
#  'BEL/USDT',
#  'BORA/USDT',
#  'BOND/USDT',
#  'BTM/USDT',
#  'BURGER/USDT',
#  'CFX/USDT',
#  'CVC/USDT',
#  'CTSI/USDT',
#  'REEF/USDT',
#  'DREP/USDT',
#  'DORA/USDT',
#  'DFI/USDT',
#  'CRTS/USDT',
#  'VEMP/USDT',
#  'WAXL/USDT',
#  'FRONT/USDT',
#  'TRIVIA/USDT',
#  'FLOW/USDT',
#  'ONE/USDT',
#  'SSV/USDT',
#  'GNO/USDT',
#  'GHST/USDT',
#  'GF/USDT',
#  'PSUB/USDT',
#  'CAL1/USDT',
#  'JOY/USDT',
#  'BIGTIME/USDT',
#  'STRAX/USDT',
#  'NTRN/USDT',
#  'ETE/USDT',
#  'ORBS/USDT',
#  'KLUB/USDT',
#  'PPT/USDT',
#  'ZTX/USDT',
#  'CYCON/USDT',
#  'DKA/USDT',
#  'SSX/USDT',
#  '$REKT/USDT',
#  'NERD/USDT',
#  'OFN/USDT',
#  'TIABG/USDT',
#  'SPURS/USDT',
#  'POLYX/USDT',
#  'T2T2/USDT',
#  'JOECOIN/USDT',
#  'BEAM/USDT',
#  'POL/USDT',
#  'TOKEN/USDT',
#  'MEMECOIN/USDT',
#  'TIA/USDT',
#  'SUNDAE/USDT',
#  'SEX/USDT',
#  'DCK/USDT',
#  'SAKAI/USDT',
#  'USDV/USDT',
#  'MBL/USDT',
#  'HMTT/USDT',
#  'VV/USDT',
#  'TRC/USDT',
#  'SHRAP/USDT',
#  'BTG/USDT',
#  'SATS/USDT',
#  'ADF/USDT',
#  'NAKA/USDT',
#  'GROK/USDT',
#  'HIFI/USDT',
#  'CHAPZ/USDT',
#  'D3D/USDT',
#  'CRE/USDT',
#  'RATS/USDT',
#  'ROOT/USDT',
#  'RXRP/USDT',
#  '10SET/USDT',
#  'HIPP/USDT',
#  'PYTH/USDT',
#  'VRTX/USDT',
#  'LSD7/USDT',
#  'VIC/USDT',
#  'PLX/USDT',
#  'BLASTBG/USDT',
#  'CAGA/USDT',
#  'ZKS/USDT',
#  'HOLD/USDT',
#  'MYRO/USDT',
#  'GMEE/USDT',
#  'F3/USDT',
#  'FIDA/USDT',
#  'BABYGROK/USDT',
#  'MYRIA/USDT',
#  'VOXEL/USDT',
#  'GSWIFT/USDT',
#  'XRD/USDT',
#  'CVTX/USDT',
#  'INSP/USDT',
#  'ARK/USDT',
#  'ULTIMA/USDT',
#  'LSK/USDT',
#  'VANRY/USDT',
#  'CETUS/USDT',
#  'XELS/USDT',
#  'LIMO/USDT',
#  'JTO/USDT',
#  'ZKPEPE/USDT',
#  'RIO/USDT',
#  'PMPY/USDT',
#  'CATE/USDT',
#  'SWCH/USDT',
#  'VINU/USDT',
#  'LMWR/USDT',
#  'ETHF/USDT',
#  'TURT/USDT',
#  'IQ/USDT',
#  'SAMO/USDT',
#  'INJ/USDT',
#  'GXE/USDT',
#  'IDEX/USDT',
#  'PGT/USDT',
#  'KOK/USDT',
#  'KEY/USDT',
#  'SNFT/USDT',
#  'BRAZIL/USDT',
#  'SEAM/USDT',
#  'ACE/USDT',
#  'MBX/USDT',
#  'MUBI/USDT',
#  'BRISE/USDT',
#  'GMX/USDT',
#  'CTC/USDT',
#  'LEVER/USDT',
#  'ALEX/USDT',
#  'LOKA/USDT',
#  'OVL3/USDT',
#  'LIT/USDT',
#  'ALU/USDT',
#  'NEBL/USDT',
#  'EFIL/USDT',
#  'XEN/USDT',
#  'MIR/USDT',
#  'MITH/USDT',
#  'MTL/USDT',
#  'MIX/USDT',
#  'MSOL/USDT',
#  'MXC/USDT',
#  'MFT/USDT',
#  'NU/USDT',
#  'TOKKI/USDT',
#  'ORN/USDT',
#  'OG/USDT',
#  'OXT/USDT',
#  'PHB/USDT',
#  'PERL/USDT',
#  'PLA/USDT',
#  'PROM/USDT',
#  'POWR/USDT',
#  'PYR/USDT',
#  'PUNDIX/USDT',
#  'POND/USDT',
#  'TAMA/USDT',
#  'KOM/USDT',
#  'TOMO/USDT',
#  'TT/USDT',
#  'QNT/USDT',
#  'QKC/USDT',
#  'REP/USDT',
#  'ROUTE/USDT',
#  'XWG/USDT',
#  'APT/USDT',
#  'SAITAMA/USDT',
#  'RED/USDT',
#  'SNM/USDT',
#  'SOC/USDT',
#  'STPT/USDT',
#  'PRMX/USDT',
#  'SYN/USDT',
#  'STMX/USDT',
#  'TRB/USDT',
#  'TWT/USDT',
#  'TITAN/USDT',
#  'T/USDT',
#  'UNFI/USDT',
#  'THE/USDT',
#  'ITA/USDT',
#  'VIB/USDT',
#  'XCN/USDT',
#  'XPR/USDT',
#  'WING/USDT',
#  'AZERO/USDT',
#  'GOO/USDT',
#  'RIF/USDT',
#  'RAD/USDT',
#  'HFT/USDT',
#  'PUMLX/USDT',
#  'KAVA/USDT',
#  'MOON/USDT',
#  'ONT/USDT',
#  'ONG/USDT',
#  'BRL/USDT',
#  'NULS/USDT',
#  'HOOK/USDT',
#  'PRIMAL/USDT',
#  'TIME/USDT',
#  'AXS/USDT',
#  'OAS/USDT',
#  'CHR/USDT',
#  'GEAR/USDT',
#  'STORJ/USDT',
#  'VITE/USDT',
#  'SHIB/USDT',
#  'GNS/USDT',
#  ...]

# %%
data = fetch_bitget_data(symbols, days_to_fetch=30)
# Out:
# /var/folders/3r/df6gd3t56pq6t10_rqr2h7pr0000gn/T/ipykernel_99099/2911671879.py:19: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   since = exchange.parse8601((datetime.utcnow() - timedelta(days=days_to_fetch)).isoformat())
# Fetching data for BTC/USDT...
# Fetching data for USDT/USDT...
# Error fetching data for USDT/USDT: bitget does not have market symbol USDT/USDT
# Fetching data for ETH/USDT...
# Fetching data for IOST/USDT...
# Fetching data for LTC/USDT...
# Fetching data for BCH/USDT...
# Fetching data for QTUM/USDT...
# Fetching data for ETC/USDT...
# Fetching data for SOLS/USDT...
# Error fetching data for SOLS/USDT: bitget does not have market symbol SOLS/USDT
# Fetching data for BEBE/USDT...
# Error fetching data for BEBE/USDT: bitget does not have market symbol BEBE/USDT
# Fetching data for WILD/USDT...
# Fetching data for SPAT/USDT...
# Error fetching data for SPAT/USDT: bitget does not have market symbol SPAT/USDT
# Fetching data for POLC/USDT...
# Error fetching data for POLC/USDT: bitget does not have market symbol POLC/USDT
# Fetching data for OVR/USDT...
# Error fetching data for OVR/USDT: bitget does not have market symbol OVR/USDT
# Fetching data for RGT/USDT...
# Error fetching data for RGT/USDT: bitget does not have market symbol RGT/USDT
# Fetching data for WKD/USDT...
# Error fetching data for WKD/USDT: bitget does not have market symbol WKD/USDT
# Fetching data for DERI/USDT...
# Error fetching data for DERI/USDT: bitget does not have market symbol DERI/USDT
# Fetching data for TAT/USDT...
# Error fetching data for TAT/USDT: bitget does not have market symbol TAT/USDT
# Fetching data for ETERNAL/USDT...
# Error fetching data for ETERNAL/USDT: bitget does not have market symbol ETERNAL/USDT
# Fetching data for GM/USDT...
# Error fetching data for GM/USDT: bitget does not have market symbol GM/USDT
# Fetching data for BIOT/USDT...
# Error fetching data for BIOT/USDT: bitget does not have market symbol BIOT/USDT
# Fetching data for CYCLUB/USDT...
# Error fetching data for CYCLUB/USDT: bitget does not have market symbol CYCLUB/USDT
# Fetching data for DOTR/USDT...
# Error fetching data for DOTR/USDT: bitget does not have market symbol DOTR/USDT
# Fetching data for CRO/USDT...
# Fetching data for VVS/USDT...
# Error fetching data for VVS/USDT: bitget does not have market symbol VVS/USDT
# Fetching data for XEM/USDT...
# Fetching data for RVN/USDT...
# Fetching data for CKB/USDT...
# Fetching data for IOTA/USDT...
# Error fetching data for IOTA/USDT: bitget does not have market symbol IOTA/USDT
# Fetching data for ICX/USDT...
# Fetching data for ALGO/USDT...
# Fetching data for TON/USDT...
# Fetching data for XVG/USDT...
# Error fetching data for XVG/USDT: bitget does not have market symbol XVG/USDT
# Fetching data for PIRATE/USDT...
# Error fetching data for PIRATE/USDT: bitget does not have market symbol PIRATE/USDT
# Fetching data for VET/USDT...
# Fetching data for TAIKO/USDT...
# Fetching data for BB/USDT...

# %%
data.columns
# Out:
# MultiIndex([(  'BTCUSDT',   'open'),
#             (  'BTCUSDT',   'high'),
#             (  'BTCUSDT',    'low'),
#             (  'BTCUSDT',  'close'),
#             (  'BTCUSDT', 'volume'),
#             (  'ETHUSDT',   'open'),
#             (  'ETHUSDT',   'high'),
#             (  'ETHUSDT',    'low'),
#             (  'ETHUSDT',  'close'),
#             (  'ETHUSDT', 'volume'),
#             ...
#             ('TAIKOUSDT',   'open'),
#             ('TAIKOUSDT',   'high'),
#             ('TAIKOUSDT',    'low'),
#             ('TAIKOUSDT',  'close'),
#             ('TAIKOUSDT', 'volume'),
#             (   'BBUSDT',   'open'),
#             (   'BBUSDT',   'high'),
#             (   'BBUSDT',    'low'),
#             (   'BBUSDT',  'close'),
#             (   'BBUSDT', 'volume')],
#            length=1895)

# %%
1985/5
# Out:
# 397.0

# %%
exchange = ccxt.bitget()
markets = exchange.load_markets()

# %%
available_symbols = set(markets.keys())

# %%
available_symbols
# Out:
# {'H/USDT:USDT',
#  'ULTI/USDT',
#  'X/USDT',
#  'HIVE/USDT:USDT',
#  '1000RATS/USDT:USDT',
#  'BGB/ETH',
#  'LMWR/USDT',
#  'AI16Z/USDT',
#  'APT/USDC',
#  'KAITO/USDT',
#  'MAV/USDT:USDT',
#  'ARB/USDC:USDC',
#  'CUDIS/USDT:USDT',
#  'AR/USDT',
#  'STX/USDT:USDT',
#  'BSV/USDT:USDT',
#  'NAVX/USDT',
#  'BOME/USDT:USDT',
#  'AXL/USDT',
#  'ORCL/USDT:USDT',
#  'NEWT/USDT:USDT',
#  'W/USDT:USDT',
#  'VINE/USDT:USDT',
#  'FUSE/USDT',
#  'ENA/USDT:USDT',
#  'ALICE/USDT:USDT',
#  'KERNEL/USDT',
#  'BTC/USD:BTC',
#  'CHZ/USDT:USDT',
#  'IDOL/USDT',
#  'MBOX/USDT',
#  'NFP/USDT',
#  'DOT/USD:DOT',
#  'JASMY/USDT',
#  'SAND/USDT:USDT',
#  'SLERF/USDT:USDT',
#  'ENA/EUR',
#  'WOLF/USDT',
#  'ALGO/USDT',
#  'HIVE/USDT',
#  'BCH/USDC',
#  'CETUS/USDT',
#  'BCH/USDT:USDT',
#  'SOL/USDT',
#  'BTC/USDC',
#  'CESS/USDT',
#  '1000XEC/USDT:USDT',
#  'KILO/USDT',
#  'AAVE/USDT:USDT',
#  'AIOZ/USDT:USDT',
#  'APT/USD:APT',
#  'RPL/USDT',
#  'STX/USDC:USDC',
#  'EGLD/USDT:USDT',
#  'PRCL/USDT',
#  'HOME/USDT:USDT',
#  'FET/USDT:USDT',
#  'AVAX/USDT',
#  'GHST/USDT:USDT',
#  'BAT/USDT:USDT',
#  'XCX/USDT:USDT',
#  'WLD/USDC:USDC',
#  'SPK/USDT',
#  'BIO/USDT:USDT',
#  '1000CAT/USDT:USDT',
#  'UPC/USDT',
#  'GMX/USDT:USDT',
#  'ERA/USDT',
#  'K/USDT',
#  'NEIROETH/USDT',
#  'ACH/USDT',
#  'XRP/USDC:USDC',
#  'CTSI/USDT:USDT',
#  'UNITE/USDT',
#  'ANI/USDT',
#  'BNT/USDT',
#  'ANKR/USDT',
#  'TON/EUR',
#  'TAC/USDT:USDT',
#  'SAHARA/USDT:USDT',
#  'VOXEL/USDT',
#  'SYS/USDT:USDT',
#  'PORTALS/USDT:USDT',
#  'TLM/USDT:USDT',
#  'AI16Z/USDT:USDT',
#  'ADA/USDC:USDC',
#  'KMNO/USDT:USDT',
#  'SOL/USDE',
#  'FUN/USDT:USDT',
#  'XAI/USDT',
#  'COMP/USDT',
#  'MELANIA/USDT',
#  'IBM/USDT:USDT',
#  'IP/USDC:USDC',
#  'CHR/USDT:USDT',
#  'QUBIC/USDT',
#  'API3/USDT',
#  'WIF/USDC:USDC',
#  'NIL/USDT:USDT',
#  'EIGEN/USDC:USDC',
#  'TON/USDC:USDC',
#  'B/USDT:USDT',
#  'SPELL/USDT',
#  'PIPPIN/USDT:USDT',
#  'ADA/USDC',
#  'CYBER/USDT:USDT',
#  'MSFT/USDT:USDT',
#  'MBL/USDT',
#  'AUCTION/USDT',
#  'RON/USDT:USDT',
#  'SOL/USDC',
#  'TRX/ETH',
#  'CFX/USDT',
#  'OG/USDT',
#  'ETH/USDC:USDC',
#  'OAS/USDT',
#  'NMT/USDT',
#  'TRUMP/USDT',
#  'BGSOL/USDT',
#  'IDEX/USDT',
#  'CATI/USDC:USDC',
#  'STORJ/USDT',
#  'ETH/USD:ETH-250926',
#  'SUI/USDC:USDC',
#  'GUN/USDT',
#  'AIN/USDT',
#  'LTC/BTC',
#  'SXRP/SUSDT:SUSDT',
#  'ANIME/USDT:USDT',
#  'BICO/USDT:USDT',
#  'ADA/USDT',
#  'ALE/USDT',
#  'PPT/USDT',
#  'QUICK/USDT',
#  'BNB/USDC',
#  'DRIFT/USDT:USDT',
#  'AERO/USDT',
#  'DUCK/USDT:USDT',
#  'WHY/USDT',
#  'SONIC/USDT:USDT',
#  'PHY/USDT',
#  'CAKE/USDT',
#  'LNQ/USDT',
#  'MDT/USDT',
#  'NTRN/USDT',
#  'DAI/USDT',
#  'RSS3/USDT',
#  'VANRY/USDT',
#  'A2Z/USDT',
#  'PNUT/USDC:USDC',
#  'GLM/USDT:USDT',
#  'PUMPBTC/USDT:USDT',
#  'BANK/USDT:USDT',
#  'FIDA/USDT',
#  'DGC/USDT',
#  'ACT/USDT',
#  'GFAL/USDT',
#  'SLP/USDT',
#  'D/USDT',
#  '10000000AIDOGE/USDT:USDT',
#  'MINA/USDC',
#  'ACX/USDT',
#  'DTEC/USDT',
#  'USDE/USDT',
#  'SOL/USD1',
#  'K/USDT:USDT',
#  'LUNA/USDT',
#  'DYDX/USDT:USDT',
#  'SNT/USDT',
#  'DOG/USDT',
#  'ROAM/USDT:USDT',
#  'NEO/USDT',
#  'SUSHI/USDT:USDT',
#  'BROCCOLI/USDT',
#  'EGL1/USDT',
#  'CVC/USDT:USDT',
#  'PIPPIN/USDT',
#  'PROMPT/USDT',
#  'SAGA/USDT:USDT',
#  'QTUM/USDT:USDT',
#  'ATOM/BTC',
#  'OPEN/USDT:USDT',
#  'USD1/USDT',
#  'AVAX/USDT:USDT',
#  'MCH/USDT',
#  'ZETA/USDT:USDT',
#  'AKT/USDT:USDT',
#  'TAO/USDC',
#  'PYR/USDT',
#  'LINK/EUR',
#  'SWEAT/USDT',
#  'ART/USDT',
#  'SOL/USDT:USDT',
#  'NOT/USDT',
#  'XAUT/USDT:USDT',
#  'HBAR/USDT:USDT',
#  'SKY/USDT:USDT',
#  'RHEA/USDT',
#  'NAVX/USDT:USDT',
#  'OXT/USDT',
#  'RWA/USDT',
#  'STEEM/USDT:USDT',
#  'SIGN/USDT:USDT',
#  'WIF/USDT',
#  'ME/USDC:USDC',
#  'COTI/USDT',
#  'BAN/USDT',
#  'FLOW/USDT:USDT',
#  'NXPC/USDT',
#  'COMP/USDT:USDT',
#  'B2/USDT:USDT',
#  'CROSS/USDT',
#  'BERA/USDT',
#  'AXS/USDT:USDT',
#  'PROM/USDT:USDT',
#  'WAI/USDT',
#  'MERL/USDT:USDT',
#  'BTC/USD1',
#  'STRK/USDT:USDT',
#  'DUSK/USDT',
#  'KAVA/USDT:USDT',
#  'KLV/USDT',
#  'CTC/USDT:USDT',
#  'PUNDIX/USDT:USDT',
#  'ISLAND/USDT',
#  'OPEN/USDT',
#  'IDOL/USDT:USDT',
#  'MBOX/USDT:USDT',
#  'U2U/USDT',
#  'DIA/USDT:USDT',
#  'IOTX/USDT:USDT',
#  'IMX/USDT',
#  'GHST/USDT',
#  'ROAM/USDT',
#  'ICX/USDT:USDT',
#  'AEVO/USDT',
#  'S/USDT',
#  'UMA/USDT',
#  'ETH/BTC',
#  'C98/USDT',
#  '1000BONK/USDT:USDT',
#  'CSPR/USDT',
#  'FXS/USDT:USDT',
#  'BRETT/USDT:USDT',
#  'GNO/USDT',
#  'ALGO/USDT:USDT',
#  'LA/USDT',
#  'ID/USDT',
#  'OBT/USDT:USDT',
#  'VIRTUAL/USDT:USDT',
#  'LPT/USDT:USDT',
#  'NAORIS/USDT',
#  'RED/USDT',
#  'UNI/USDC',
#  'WAVES/USDT:USDT',
#  'CELO/USDT:USDT',
#  'JST/USDT:USDT',
#  'SOL/USDC:USDC',
#  'ALGO/USDC:USDC',
#  'AGI/USDT:USDT',
#  'ZKJ/USDT:USDT',
#  'SWGT/USDT',
#  'SATS/USDT',
#  'PERP/USDT',
#  'AL/USDT',
#  'PENDLE/USDT',
#  'BADGER/USDT:USDT',
#  'CVX/USDT',
#  'SXT/USDT:USDT',
#  'KUB/USDT',
#  'HIPPO/USDT',
#  'XRP/BTC',
#  'AVAAI/USDT:USDT',
#  'SAND/USDT',
#  'CHR/USDT',
#  'J/USDT',
#  'FIS/USDT',
#  'BTC/RLUSD',
#  'TRUMP/USDC',
#  'BAN/USDT:USDT',
#  'FET/USDT',
#  'ENJ/USDT:USDT',
#  'COW/USDT:USDT',
#  'VT/USDT',
#  'GATA/USDT',
#  'TRB/USDT',
#  'XLM/USDC:USDC',
#  'NEAR/USD:NEAR',
#  'SWTCH/USDT',
#  'ALPHA/USDT:USDT',
#  'ANKR/USDT:USDT',
#  'POL/USDT:USDT',
#  'MUBARAK/USDT',
#  'PENGU/USDC:USDC',
#  'B3/USDT:USDT',
#  'PEPE/USDC',
#  '1000000MOG/USDT:USDT',
#  'LINEA/USDT:USDT',
#  'ELON/USDT',
#  'IN/USDT',
#  'T/USDT:USDT',
#  'MOVR/USDT:USDT',
#  'DOGE/USDC',
#  'SOPH/USDT',
#  'HFT/USDT',
#  'SCR/EUR',
#  'VIC/USDT',
#  'ADA/USDT:USDT',
#  'PUFFER/USDT:USDT',
#  'ENA/USDC',
#  'QKC/USDT',
#  'ETC/USDT:USDT',
#  'ALGO/USDC',
#  'SUN/USDT',
#  'DENT/USDT',
#  'AVAX/USDC',
#  'LSK/USDT',
#  'WOO/USDT:USDT',
#  'BSV/USDT',
#  'STG/USDT:USDT',
#  'SLERF/USDT',
#  'WIN/USDT',
#  'JTO/USDT',
#  'LA/USDT:USDT',
#  'FLM/USDT:USDT',
#  'AEVO/USDC:USDC',
#  'WLFI/USDC:USDC',
#  'TSTBSC/USDT:USDT',
#  'AINETH/USDT',
#  'GNO/USDT:USDT',
#  'CRV/USDT:USDT',
#  'WLD/USDT:USDT',
#  'EIGEN/USDT',
#  'XRP/EUR',
#  'ETHW/USDT',
#  'AVL/USDT:USDT',
#  'FORTH/USDT:USDT',
#  'ENA/USDT',
#  'TRX/USD:TRX',
#  'LAYER/USDT:USDT',
#  'LINK/USD:LINK',
#  'NVDA/USDT:USDT',
#  'DEUSD/USDT',
#  'SCR/USDT:USDT',
#  'WILD/USDT',
#  'RVN/USDT',
#  'CORE/USDT:USDT',
#  'REZ/USDT',
#  'BABA/USDT:USDT',
#  'ID/USDT:USDT',
#  'BID/USDT:USDT',
#  'Q/USDT',
#  'SYN/USDT',
#  'GLM/USDT',
#  'CETUS/USDT:USDT',
#  'FUEL/USDT:USDT',
#  'NFT/USDT',
#  'ARB/USDT:USDT',
#  'GEAR/USDT',
#  'POPCAT/USDT:USDT',
#  'HYPER/USDT:USDT',
#  'HTX/USDT',
#  'SWARMS/USDT',
#  'ZEREBRO/USDT:USDT',
#  'HOT/USDT:USDT',
#  'RDNT/USDT',
#  'VELO/USDT:USDT',
#  'ML/USDT',
#  'DOT/USDT',
#  'DEXE/USDT:USDT',
#  'DOOD/USDT',
#  'RLC/USDT',
#  '1MBABYDOGE/USDT:USDT',
#  'OBOL/USDT',
#  'ENS/USDT',
#  'ILV/USDT',
#  'HEI/USDT',
#  'SHIB/USDT:USDT',
#  '0G/USDT',
#  'LISTA/USDT',
#  'IP/USDT:USDT',
#  'MSTR/USDT:USDT',
#  'VET/USDT',
#  'BLUR/USDT:USDT',
#  'MASA/USDT',
#  'WAVES/USDT',
#  'CHESS/USDT:USDT',
#  'GAS/USDT',
#  'BAL/USDT',
#  'ZENT/USDT',
#  'ORDER/USDT:USDT',
#  'ARB/USDT',
#  'DUCK/USDT',
#  'F/USDT',
#  'SBTC/SUSDT',
#  'ARB/USDC',
#  'USDT/BRL',
#  'CORE/USDT',
#  'ARKM/USDT',
#  'ZKWASM/USDT',
#  'LRC/USDT',
#  'BAT/USDT',
#  'AXS/USDT',
#  'AAVE/USDC:USDC',
#  'BIGTIME/USDT:USDT',
#  'SOL/BTC',
#  'MERL/USDT',
#  'ALT/USDT:USDT',
#  'VOXEL/USDT:USDT',
#  'HUMA/USDT:USDT',
#  'CAMP/USDT',
#  'HOUSE/USDT',
#  'PLUME/USDT:USDT',
#  'MITO/USDT:USDT',
#  'DOGS/USDT',
#  'CYBER/USDT',
#  'DOLO/USDT:USDT',
#  'PCI/USDT',
#  'TLOS/USDT',
#  'CRV/USDC:USDC',
#  'MYRIA/USDT',
#  'SWELL/USDT',
#  'DOGS/USDT:USDT',
#  'NEXO/USDT',
#  'NEAR/USDC:USDC',
#  'FHE/USDT:USDT',
#  'ZKJ/USDT',
#  'ALCH/USDT:USDT',
#  'ENS/USDC:USDC',
#  'FIL/USDC',
#  'SBTC/SUSDC:SUSDC',
#  'NXPC/USDT:USDT',
#  'GME/USDT:USDT',
#  'TRU/USDT:USDT',
#  'OGN/USDT:USDT',
#  'RSR/USDT:USDT',
#  'AERGO/USDT',
#  'MAK/USDT',
#  'ZEREBRO/USDT',
#  'ORCA/USDT:USDT',
#  'ZRX/USDT:USDT',
#  'XCN/USDT:USDT',
#  'ANLOG/USDT',
#  'MASK/USDT:USDT',
#  'BGSC/USDT',
#  'POWR/USDT:USDT',
#  'ZK/USDT',
#  'SNT/USDT:USDT',
#  'HAEDAL/USDT:USDT',
#  'USDE/USDC',
#  'BLESS/USDT',
#  'BGB/EUR',
#  'SAFE/USDT',
#  'ZIL/USDT',
#  'TRX/USDT:USDT',
#  'PREMARKET3/USDT',
#  'NAORIS/USDT:USDT',
#  'ETHFI/USDT:USDT',
#  'RPL/USDT:USDT',
#  'BANANAS31/USDT',
#  'ARK/USDT:USDT',
#  'GALFAN/USDT',
#  'GIGA/USDT:USDT',
#  'STO/USDT',
#  'DOOD/USDT:USDT',
#  'MBX/USDT',
#  'PYR/USDT:USDT',
#  'BGB/USDT',
#  'GE/USDT:USDT',
#  'DegenReborn/USDT',
#  'OM/USDT',
#  'PHB/USDT:USDT',
#  'USUAL/USDT:USDT',
#  'QUICK/USDT:USDT',
#  'FORM/USDT:USDT',
#  'IAG/USDT',
#  'VET/USDT:USDT',
#  'AIN/USDT:USDT',
#  'RLUSD/USDT',
#  'HNT/USDT',
#  'AI/USDT',
#  'SONIC/USDT',
#  'TA/USDT:USDT',
#  'AIXBT/USDT',
#  'SXP/USDT',
#  'AAVE/USDT',
#  'BEL/USDT:USDT',
#  'MAJOR/USDT:USDT',
#  'XRP/USD1',
#  'GORK/USDT',
#  'FORM/USDT',
#  'ETH/BRL',
#  'PYTH/USDT:USDT',
#  'POL/USDC',
#  'XCX/USDT',
#  'SBTC/SUSD:SBTC-250926',
#  'UMA/USDT:USDT',
#  'ORDI/BTC',
#  'ALPH/USDT',
#  'SNX/USDT',
#  'AVNT/USDT:USDT',
#  'JOE/USDT',
#  'ALPHA/USDT',
#  'B/USDT',
#  'G/USDT:USDT',
#  'AVA/USDT',
#  'KOMA/USDT:USDT',
#  'C/USDT:USDT',
#  'OP/USDC:USDC',
#  'ETHFI/USDT',
#  'WIF/USD:WIF',
#  'MORPHO/USDT:USDT',
#  'WAXP/USDT:USDT',
#  'XTER/USDT',
#  'NEWT/USDT',
#  'SHIB/EUR',
#  'WBTC/USDT',
#  'BABYDOGE/USDT',
#  'SAGA/USDT',
#  'BONK/USDT',
#  'FLOKI/USDT:USDT',
#  'VANA/USDC:USDC',
#  'HOME/USDT',
#  'IQ/USDT',
#  'BLUE/USDT:USDT',
#  'OL/USDT:USDT',
#  'LUMIA/USDT',
#  'MX/USDT',
#  'RFC/USDT',
#  'SSV/USDT:USDT',
#  'XCAD/USDT',
#  'LTC/USDC',
#  'WAL/USDT:USDT',
#  'GRASS/USDT',
#  'THE/USDT',
#  'WEN/USDT',
#  'FWOG/USDT:USDT',
#  'ETH/USD:ETH',
#  'BLUM/USDT',
#  'USDC/EUR',
#  'THINK/USDT',
#  'MILK/USDT:USDT',
#  'FXS/USDT',
#  'PARTI/USDT:USDT',
#  'SPELL/USDT:USDT',
#  'TCOM/USDT',
#  'CFX/USDT:USDT',
#  'HIGH/USDT',
#  'KAIA/USDT',
#  'BLUR/USDT',
#  'CRCL/USDT:USDT',
#  'PARTI/USDT',
#  'ETH/USDT',
#  'ATA/USDT:USDT',
#  'XDC/USDT:USDT',
#  'BABY/USDT',
#  'BB/USDT',
#  'DOGE/EUR',
#  'BMT/USDT:USDT',
#  'TSLA/USDT:USDT',
#  'SKYAI/USDT',
#  'INJ/USDT',
#  'SKL/USDT:USDT',
#  'HFT/USDT:USDT',
#  'SBTC/SUSD:SBTC',
#  'VIRTUAL/USDT',
#  'RVN/USDT:USDT',
#  'CAR/USDT',
#  'NERO/USDT',
#  'XCN/USDT',
#  'XION/USDT:USDT',
#  'FARTCOIN/USDC:USDC',
#  'ACE/USDT:USDT',
#  'GAME2/USDT',
#  'BLAST/USDT:USDT',
#  'RIVER/USDT',
#  'BTC/BRL',
#  'SKYAI/USDT:USDT',
#  'PAXG/USDT',
#  'ORDI/USDC:USDC',
#  'BTC/WUSD',
#  'PUBLIC/USDT',
#  'CELR/USDT',
#  'UNI/USDC:USDC',
#  'PRCL/USDT:USDT',
#  'MINA/USDT',
#  'PORTO/USDT',
#  'LAZIO/USDT',
#  'SUN/USDT:USDT',
#  'SERAPH/USDT:USDT',
#  'ONG/USDT:USDT',
#  'METIS/USDT:USDT',
#  'ETHW/USDT:USDT',
#  'LINK/USDT',
#  '1INCH/USDT:USDT',
#  'ACH/USDT:USDT',
#  'PORTALS/USDT',
#  'JUP/USDT:USDT',
#  'ONDO/EUR',
#  'SAFE/USDT:USDT',
#  'PENDLE/USDT:USDT',
#  'TOMA/USDT',
#  'ZRC/USDT:USDT',
#  'NODE/USDT',
#  'DegenReborn/USDT:USDT',
#  'SUI/EUR',
#  'NEIROCTO/EUR',
#  'SCA/USDT',
#  'FAIR3/USDT',
#  'MUBARAK/USDT:USDT',
#  'HBAR/USDT',
#  'RENDER/USDT',
#  'NESS/USDT',
#  'PEOPLE/USDT',
#  'BTC/USDT:USDT',
#  'OG/USDT:USDT',
#  'STETH/USDT',
#  'UXLINK/USDT:USDT',
#  'W/USDT',
#  'USUAL/USDT',
#  'NS/USDT',
#  'USELESS/USDT:USDT',
#  'BTT/USDT',
#  'ARTFI/USDT',
#  'SYN/USDT:USDT',
#  'YZY/USDT',
#  'LISTA/USDT:USDT',
#  'ARM/USDT:USDT',
#  'SETH/SBTC',
#  'TRX/USDT',
#  'C98/USDT:USDT',
#  'SOON/USDT:USDT',
#  'TAIKO/USDT:USDT',
#  'ORDER/USDT',
#  'FET/USDC',
#  'USTC/USDT',
#  'H/USDT',
#  'SETH/SUSD:SETH-250926',
#  'GODS/USDT:USDT',
#  'KAITO/USDC:USDC',
#  'BLUE/USDT',
#  'REZ/USDT:USDT',
#  'SHIB/USDT',
#  'INIT/USDT:USDT',
#  'M/USDT',
#  'ETH/USDT:USDT',
#  'CBK/USDT',
#  'CHESS/USDT',
#  'PSTAKE/USDT',
#  'REI/USDT:USDT',
#  'BB/USDT:USDT',
#  'TON/USDT:USDT',
#  'J/USDT:USDT',
#  'MYRO/USDT',
#  'PYTH/USDT',
#  'GMX/USDT',
#  'PTB/USDT',
#  'CHILLGUY/USDT',
#  'DOGE/USDC:USDC',
#  'COW/USDT',
#  '0G/USDT:USDT',
#  'NAKA/USDT',
#  'LIVE/USDT',
#  'IMX/USDT:USDT',
#  'XPR/USDT',
#  'AIO/USDT:USDT',
#  'VTHO/USDT',
#  '1INCH/USDT',
#  'BEAM/USDT',
#  'KNC/USDT',
#  'SD/USDT',
#  'LINK/USDC:USDC',
#  'JASMY/USDT:USDT',
#  'META/USDT:USDT',
#  'ETHFI/USDC:USDC',
#  'LDO/USDT',
#  'ZORA/USDT',
#  'UNI/USDT:USDT',
#  'USDC/USDT:USDT',
#  'ALPINE/USDT:USDT',
#  'ROSE/USDT:USDT',
#  'COQ/USDT',
#  'CTSI/USDT',
#  'COA/USDT',
#  'MTL/USDT',
#  'PEPE/USDT',
#  'POLYX/USDT',
#  'XAUT/USDT',
#  'ELF/USDT',
#  'IOST/USDT:USDT',
#  'LOOKS/USDT:USDT',
#  'TRU/USDT',
#  'ONT/USDT:USDT',
#  'FHE/USDT',
#  'ICE/USDT',
#  'OGN/USDT',
#  'AVAIL/USDT:USDT',
#  'ICP/USDT',
#  'SLN/USDT',
#  'PI/USDT',
#  'AVAX/EUR',
#  'AUDIO/USDT:USDT',
#  'MOEW/USDT',
#  'CRV/BTC',
#  'SUNDOG/USDT:USDT',
#  'FRAG/USDT',
#  'DENT/USDT:USDT',
#  'STX/USDT',
#  'SWEAT/USDT:USDT',
#  'ALICE/USDT',
#  'GODS/USDT',
#  'LDO/USDT:USDT',
#  'QNT/USDT:USDT',
#  'GORK/USDT:USDT',
#  'TAO/USDT',
#  'ZRO/USDT:USDT',
#  'BOOST/USDT',
#  'MEW/USDT:USDT',
#  'TOWNS/USDT',
#  'TIA/USDT:USDT',
#  'SOLV/USDT',
#  'A/USDT:USDT',
#  'POND/USDT',
#  'B2/USDT',
#  'KAVA/USDT',
#  'LTC/ETH',
#  'PI/USDC:USDC',
#  'DYDX/USDT',
#  'MANTA/USDT:USDT',
#  'ME/USDT:USDT',
#  'BABY/USDT:USDT',
#  'APT/USDC:USDC',
#  'IO/USDT',
#  'PSG/USDT',
#  'IOST/USDT',
#  'BTC/USDE',
#  'VOLT/USDT',
#  'EPT/USDT',
#  'HIPPO/USDT:USDT',
#  'BNB/USDT:USDT',
#  'WOO/USDT',
#  'ATH/USDT:USDT',
#  'AITECH/USDT',
#  'FUEL/USDT',
#  'MOG/USDT',
#  'ANIME/USDT',
#  'NPC/USDT',
#  'KAS/USDT',
#  'MRVL/USDT:USDT',
#  'DFDV/USDT:USDT',
#  'PROVE/USDT',
#  'GPS/USDT:USDT',
#  'INIT/USDT',
#  'SETH/SUSDC:SUSDC',
#  'AVAX/USDC:USDC',
#  'APE/USDT',
#  'APE/USDT:USDT',
#  'WIF/EUR',
#  'NFP/USDT:USDT',
#  'VANRY/USDT:USDT',
#  'PUNDIX/USDT',
#  'AXL/USDT:USDT',
#  'MAPO/USDT',
#  'COTI/USDT:USDT',
#  'COOKIE/USDT',
#  'HOLO/USDT:USDT',
#  'AIA/USDT',
#  'LSK/USDT:USDT',
#  'RSS3/USDT:USDT',
#  'NKN/USDT',
#  'KSM/USDT',
#  'AVAX/USD:AVAX',
#  'EIGEN/USDT:USDT',
#  'LABUBU/USDT',
#  'ESPORTS/USDT:USDT',
#  'XTZ/USDT',
#  'ASTR/USDT:USDT',
#  'FLOKI/USDC',
#  'KNC/USDT:USDT',
#  'HUMA/USDT',
#  'NMR/USDT',
#  'OP/USDC',
#  'NOT/USDC:USDC',
#  'OP/USDT',
#  'ORBS/USDT',
#  'SPK/USDT:USDT',
#  'GAIA/USDT',
#  'ME/USDT',
#  'ONT/USDT',
#  'RIOT/USDT:USDT',
#  'SHIB/USDC:USDC',
#  'MLN/USDT:USDT',
#  'A/USDT',
#  'HEI/USDT:USDT',
#  'CKB/USDT',
#  'SEI/USDT:USDT',
#  'AVA/USDT:USDT',
#  'XLM/USDT:USDT',
#  'ERA/USDT:USDT',
#  'ASTER/USDT:USDT',
#  'ATM/USDT',
#  'AAVE/USD:AAVE',
#  'LAUNCHCOIN/USDT:USDT',
#  'LTC/USDT:USDT',
#  'ICNT/USDT',
#  'SWCH/USDT',
#  'BANK/USDT',
#  'SXT/USDT',
#  'HEMI/USDT:USDT',
#  'APT/USDT',
#  'ALT/USDT',
#  'PONKE/USDT',
#  'SHELL/USDT',
#  'IOTA/USDT:USDT',
#  'TAO/USDT:USDT',
#  'DRIFT/USDT',
#  'DODO/USDT',
#  'AGLD/USDT:USDT',
#  'ACT/USDT:USDT',
#  'CHZ/USDT',
#  'GLMR/USDT',
#  'TRUMP/USDC:USDC',
#  '1000SATS/USDT:USDT',
#  'BERA/USDT:USDT',
#  'MYX/USDT',
#  'RAY/USDT',
#  'C/USDT',
#  'XLM/USDT',
#  'BGSC/USDT:USDT',
#  'MEME/USDT',
#  'MEME/USDT:USDT',
#  'BR/USDT',
#  'MAJOR/USDT',
#  'ETH/USDE',
#  'SFP/USDT',
#  'LQTY/USDT:USDT',
#  'SDEX/USDT',
#  'HAEDAL/USDT',
#  'TREE/USDT:USDT',
#  'APP/USDT:USDT',
#  'NODE/USDT:USDT',
#  'TIA/USDT',
#  'AWE/USDT',
#  'VELVET/USDT:USDT',
#  'ZBCN/USDT',
#  'ACE/USDT',
#  'ALCH/USDT',
#  'BMT/USDT',
#  'CROSS/USDT:USDT',
#  'ZRO/USDT',
#  'BCH/USDC:USDC',
#  'VELODROME/USDT',
#  'SAHARA/USDT',
#  'RESOLV/USDT',
#  'POL/USDT',
#  'INTC/USDT:USDT',
#  'WCT/USDT:USDT',
#  'USDC/USDT',
#  'SHIB/USDC',
#  'AIDOGE/USDT',
#  'ONE/USDT:USDT',
#  'XVG/USDT:USDT',
#  'BIO/USDT',
#  'HOLO/USDT',
#  'AVAX/BTC',
#  'YGG/USDT',
#  'HYPE/USDT:USDT',
#  'M/USDT:USDT',
#  'TURBO/USDT',
#  'RARE/USDT',
#  'ASR/USDT:USDT',
#  'NEAR/EUR',
#  'ARKM/USDT:USDT',
#  'SIGN/USDT',
#  'PIXEL/USDT',
#  'SUI/USDC',
#  'XRP/USD:XRP',
#  'FIL/ETH',
#  'FARTCOIN/USDT:USDT',
#  'WLFI/USDT',
#  'JTO/USDT:USDT',
#  'AERGO/USDT:USDT',
#  'VELO/USDT',
#  'AMP/USDT:USDT',
#  'CGPT/USDT',
#  'GMT/USDT:USDT',
#  'TAIKO/USDT',
#  'PROM/USDT',
#  'NKN/USDT:USDT',
#  'DOGE/USDT:USDT',
#  'ZKC/USDT:USDT',
#  'KAITO/USDT:USDT',
#  'X/USDT:USDT',
#  'FLUX/USDT:USDT',
#  'TRB/USDT:USDT',
#  'HMSTR/USDT:USDT',
#  'AR/USDC',
#  'FROGGIE/USDT',
#  'SHELL/USDT:USDT',
#  'USD1/USDC',
#  'TAC/USDT',
#  'EPIC/USDT:USDT',
#  'OLAS/USDT',
#  'EOS/USDT',
#  'IKA/USDT',
#  'NOT/USDT:USDT',
#  'BTC/EUR',
#  'LINK/BTC',
#  'SUPER/USDT',
#  'ARC/USDT',
#  'GTC/USDT:USDT',
#  'EPT/USDT:USDT',
#  'AUCTION/USDT:USDT',
#  'KDA/USDT',
#  'ASP/USDT:USDT',
#  'SXRP/SUSDT',
#  'ZIG/USDT',
#  'OMNI1/USDT',
#  'LRC/USDT:USDT',
#  'ASML/USDT:USDT',
#  'POKT/USDT',
#  'PNUT/USDT',
#  'AIO/USDT',
#  'SOPH/USDC',
#  'PROPS/USDT',
#  'PLUME/USDT',
#  'DEEP/USDT',
#  'CTC/USDT',
#  'SBTC/SUSDT:SUSDT',
#  'PAXG/USDT:USDT',
#  'SETF1001/USDT',
#  'SQD/USDT:USDT',
#  'HOLD/USDT',
#  'TANSSI/USDT',
#  'TUSD/USDT',
#  'PHB/USDT',
#  'AVNT/USDT',
#  'WLD/EUR',
#  'FLOCK/USDT',
#  'LTC/EUR',
#  'SYRUP/USDT',
#  'STX/USDC',
#  'GALA/USDT:USDT',
#  'PROMPT/USDT:USDT',
#  'F/USDT:USDT',
#  'NS/USDT:USDT',
#  'SCRT/USDT:USDT',
#  'XRP/USDT',
#  'ETC/USDC:USDC',
#  'TAG/USDT',
#  'PEPE/EUR',
#  'OSMO/USDT',
#  'PEAQ/USDT:USDT',
#  'ARC/USDT:USDT',
#  'HBAR/USDC:USDC',
#  'LTC/USDT',
#  'ARK/USDT',
#  'AR/USDT:USDT',
#  'LUNA/USDT:USDT',
#  'JUP/USDT',
#  'PUMP/USDT:USDT',
#  'B/USD1',
#  'IP/USDT',
#  'AAVE/BTC',
#  'PHA/USDT:USDT',
#  'VERT/USDT',
#  'DBR/USDT:USDT',
#  'ELA/USDT',
#  'TUT/USDT:USDT',
#  'VTHO/USDT:USDT',
#  'MCADE/USDT',
#  'AUDIO/USDT',
#  'STRK/USDT',
#  'GRIFFAIN/USDT',
#  'ETC/USD:ETC',
#  'BANANAS31/USDT:USDT',
#  'CVC/USDT',
#  'REX/USDT',
#  'FIL/USDT:USDT',
#  'JELLYJELLY/USDT',
#  'MOCA/USDT',
#  'BCH/USD:BCH',
#  'FLOCK/USDT:USDT',
#  'METIS/USDT',
#  'U/USDT:USDT',
#  'ARIA/USDT:USDT',
#  'BSU/USDT',
#  'DOGE/BTC',
#  'SUSHI/USDT',
#  'CYC/USDT',
#  'NC/USDT',
#  'GPS/USDT',
#  'WCT/USDT',
#  'RUNE/USDT',
#  'CHILLGUY/USDT:USDT',
#  'FIS/USDT:USDT',
#  'ZEN/USDT',
#  'MILK/USDT',
#  'FTT/USDT',
#  'SOMI/USDT:USDT',
#  ...}

# %%
import pandas as pd
import numpy as np
import ccxt
import time
from datetime import datetime, timedelta, timezone
import requests

def strategy(df, config_dict):
    """
    Implements an intraday trading strategy that weights momentum by volume and trade imbalance.
    
    NOTE: This function is self-contained. It fetches its own data from external APIs
    and IGNORES the input DataFrame `df`. This is to comply with server environments
    where only this single function can be executed.
    """
    # --- Input validation for config_dict ---
    if not isinstance(config_dict, dict):
        raise TypeError("config_dict must be a dictionary.")

    # --- Part 1: Fetch Tradable Symbols ---
    symbols_url = "https://crypto.fin.cloud.ainode.ai/a71eaf04-802f-40be-93c2-5bee2548f4db/get/info/coin"
    print("Fetching tradable symbols...")
    try:
        response = requests.get(symbols_url)
        response.raise_for_status()
        coins_data = response.json()
        
        symbols_to_fetch = []
        for item in coins_data['data']:
            coin_name = item.get('coin_nm')
            if coin_name and coin_name.upper() != 'USDT':
                symbols_to_fetch.append(f"{coin_name}/USDT")
        
        print(f"Successfully found {len(symbols_to_fetch)} tradable symbols.")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching symbols: {e}")
        print("Using default symbols as a fallback.")
        symbols_to_fetch = ['BTC/USDT', 'ETH/USDT']

    if not symbols_to_fetch:
        print("No symbols to process. Exiting.")
        return {}

    # --- Part 2: Fetch OHLCV Data from Bitget ---
    # Fetching 1 day of 1-minute data is sufficient for a 20-minute rolling window.
    days_to_fetch = 1 
    exchange = ccxt.bitget()
    
    print("Loading available markets from Bitget...")
    try:
        markets = exchange.load_markets()
        available_symbols = set(markets.keys())
        print(f"Found {len(available_symbols)} markets on Bitget.")
    except Exception as e:
        print(f"Could not load markets from Bitget: {e}. Proceeding without market validation.")
        available_symbols = set(symbols_to_fetch)
    
    timeframe = '1m'
    since = exchange.parse8601((datetime.now(timezone.utc) - timedelta(days=days_to_fetch)).isoformat())
    
    all_symbols_data = []
    
    for symbol in symbols_to_fetch:
        if symbol not in available_symbols:
            continue

        print(f"Fetching data for {symbol}...")
        try:
            limit = 1000 # Fetch up to 1000 minutes (about 16.7 hours)
            ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit=limit)
            
            if not ohlcv:
                print(f"Warning: No data returned for {symbol}.")
                continue

            fetched_df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            fetched_df['timestamp'] = pd.to_datetime(fetched_df['timestamp'], unit='ms')
            fetched_df.set_index('timestamp', inplace=True)
            
            # --- CRITICAL DATA NOTE ---
            # The strategy requires 'takerBuyBaseTvol' which is not available in standard OHLCV data.
            # In a real-world scenario, you MUST replace this with actual data.
            # Here, we use a neutral placeholder (50% of total volume) so the logic can run.
            fetched_df['takerBuyBaseTvol'] = fetched_df['volume'] * 0.5

            fetched_df.columns = pd.MultiIndex.from_product([[symbol.replace('/', '')], fetched_df.columns])
            all_symbols_data.append(fetched_df)

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
        
        time.sleep(exchange.rateLimit / 1000)

    if not all_symbols_data:
        print("Could not fetch any data. Strategy cannot proceed.")
        return {}
        
    data_df = pd.concat(all_symbols_data, axis=1)

    # --- Part 3: Strategy Logic (Intraday Momentum-Weighted by Volume Imbalance) ---
    
    strategy_specific_config = config_dict.get("strategy_config", {})
    rolling_window = strategy_specific_config.get("rolling_window", 20)
    epsilon = 1e-9 # Small constant to avoid division by zero

    symbols_in_df = data_df.columns.get_level_values(0).unique()
    final_signals = {}

    for symbol in symbols_in_df:
        symbol_df = data_df[symbol].copy() # Use .copy() to avoid SettingWithCopyWarning
        
        # Ensure there's enough data for the rolling window
        if len(symbol_df) < rolling_window + 1:
            continue

        # 1. Minute return
        # Using .loc to prevent potential SettingWithCopyWarning
        symbol_df.loc[:, 'r_min'] = (symbol_df['close'] - symbol_df['open']) / (symbol_df['open'] + epsilon)

        # 2. Return statistics (rolling over the last 20 minutes, excluding the current minute)
        shifted_returns = symbol_df['r_min'].shift(1)
        mu_20 = shifted_returns.rolling(window=rolling_window).mean()
        sigma_20 = shifted_returns.rolling(window=rolling_window).std()

        # 3. Return z-score
        z_ret = (symbol_df['r_min'] - mu_20) / (sigma_20 + epsilon)

        # 4. Volume statistics (same 20-minute window)
        shifted_volume = symbol_df['volume'].shift(1)
        mu_vol = shifted_volume.rolling(window=rolling_window).mean()
        sigma_vol = shifted_volume.rolling(window=rolling_window).std()
        
        # 5. Volume z-score
        z_vol = (symbol_df['volume'] - mu_vol) / (sigma_vol + epsilon)

        # 6. Volume imbalance
        tvol = symbol_df['volume']
        taker_buy_vol = symbol_df['takerBuyBaseTvol']
        imb = (2 * taker_buy_vol - tvol) / (tvol + epsilon)
        
        # 7. Final signal
        signal = z_ret * z_vol * imb
        
        # Store the latest valid signal for the symbol
        if not np.isnan(signal.iloc[-1]):
            final_signals[symbol] = signal.iloc[-1]

    if not final_signals:
        print("No valid signals generated.")
        return {}

    # --- Cross-Sectional Normalization & Weight Allocation ---
    final_signals_series = pd.Series(final_signals)
    
    # Optional: Neutralize by cross-sectional z-score (can be added if desired)
    # cs_mean = final_signals_series.mean()
    # cs_std = final_signals_series.std()
    # if cs_std > 0:
    #     final_signals_series = (final_signals_series - cs_mean) / cs_std

    total_abs_signal = final_signals_series.abs().sum()
    if total_abs_signal == 0:
        return {}
        
    weights = final_signals_series / total_abs_signal
    
    print("\nCalculated Strategy Weights:")
    sorted_weights = sorted(weights.items(), key=lambda item: abs(item[1]), reverse=True)
    for symbol, weight in sorted_weights:
        print(f"  {symbol}: {weight:.6f}")
            
    return weights.to_dict()

# %%
config_params = {"strategy_config": {
    # 이동평균 및 표준편차 계산을 위한 롤링 윈도우 크기 (분 단위)
    # 전략의 핵심 파라미터입니다.
    "rolling_window": 20
  }}

# %%
config_params.get("strategy_config", {})
# Out:
# {'rolling_window': 20}

# %%
# 이 파일은 strategy.py에서 사용할 설정값을 정의합니다.
strategy_config_params = {
  "rebalancing_config": {
    # 리밸런싱 주기는 외부 스케줄러에서 사용될 수 있으나,
    # 현재 전략은 실행될 때마다 최신 분봉 데이터로 신호를 계산합니다.
    "rebalancing_interval_hours": 72,
  },
  "strategy_config": {
    # 이동평균 및 표준편차 계산을 위한 롤링 윈도우 크기 (분 단위)
    # 전략의 핵심 파라미터입니다.
    "rolling_window": 20
  }
}

# %%
import pandas as pd
import numpy as np
import ccxt
import time
from datetime import datetime, timedelta, timezone

def strategy(df, config_dict):
    """
    Implements an intraday trading strategy that weights momentum by volume and trade imbalance.
    
    NOTE: This function is self-contained. It fetches its own data directly from the exchange
    and IGNORES the input DataFrame `df`.
    """
    # --- Input validation for config_dict ---
    if not isinstance(config_dict, dict):
        raise TypeError("config_dict must be a dictionary.")

    # --- Part 1: Fetch Tradable Symbols Directly from Bitget ---
    exchange = ccxt.bitget()
    print("Loading available markets from Bitget...")
    try:
        markets = exchange.load_markets()
        # Filter for active USDT spot markets
        symbols_to_fetch = [
            m['symbol'] for m in markets.values()
            if m.get('spot') and m.get('active') and m['symbol'].endswith('/USDT')
        ]
        
        if not symbols_to_fetch:
            raise ValueError("No active USDT spot markets found on Bitget.")
        
        # Limit the number of symbols to avoid excessive API calls in a single run
        # For a real-world scenario, you might want to filter by volume or other criteria
        max_symbols = 50 
        symbols_to_fetch = symbols_to_fetch[:max_symbols]
        print(f"Found {len(symbols_to_fetch)} active USDT spot markets to process.")

    except Exception as e:
        print(f"Error fetching symbols from Bitget: {e}")
        print("Using a small default list as a fallback.")
        symbols_to_fetch = ['BTC/USDT', 'ETH/USDT', 'BGB/USDT']

    # --- Part 2: Fetch OHLCV Data from Bitget ---
    days_to_fetch = 1 
    timeframe = '1m'
    since = exchange.parse8601((datetime.now(timezone.utc) - timedelta(days=days_to_fetch)).isoformat())
    
    all_symbols_data = []
    
    for symbol in symbols_to_fetch:
        print(f"Fetching data for {symbol}...")
        try:
            limit = 1000 # Fetch up to 1000 minutes
            ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit=limit)
            
            if not ohlcv:
                print(f"Warning: No data returned for {symbol}.")
                continue

            fetched_df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            fetched_df['timestamp'] = pd.to_datetime(fetched_df['timestamp'], unit='ms')
            fetched_df.set_index('timestamp', inplace=True)
            
            # --- CRITICAL DATA NOTE ---
            # The strategy requires 'takerBuyBaseTvol' which is not available in standard OHLCV data.
            # In a real-world scenario, you MUST replace this with actual data.
            # Here, we use a neutral placeholder (50% of total volume) so the logic can run.
            fetched_df['takerBuyBaseTvol'] = fetched_df['volume'] * 0.5

            fetched_df.columns = pd.MultiIndex.from_product([[symbol.replace('/', '')], fetched_df.columns])
            all_symbols_data.append(fetched_df)

        except Exception as e:
            print(f"Error fetching data for {symbol}: {e}")
        
        time.sleep(exchange.rateLimit / 1000)

    if not all_symbols_data:
        print("Could not fetch any data. Strategy cannot proceed.")
        return {}
        
    data_df = pd.concat(all_symbols_data, axis=1)

    # --- Part 3: Strategy Logic (Intraday Momentum-Weighted by Volume Imbalance) ---
    strategy_specific_config = config_dict.get("strategy_config", {})
    rolling_window = strategy_specific_config.get("rolling_window", 20)
    epsilon = 1e-9

    symbols_in_df = data_df.columns.get_level_values(0).unique()
    final_signals = {}

    for symbol in symbols_in_df:
        symbol_df = data_df[symbol].copy()
        
        if len(symbol_df) < rolling_window + 1:
            continue

        symbol_df.loc[:, 'r_min'] = (symbol_df['close'] - symbol_df['open']) / (symbol_df['open'] + epsilon)

        shifted_returns = symbol_df['r_min'].shift(1)
        mu_20 = shifted_returns.rolling(window=rolling_window).mean()
        sigma_20 = shifted_returns.rolling(window=rolling_window).std()
        z_ret = (symbol_df['r_min'] - mu_20) / (sigma_20 + epsilon)

        shifted_volume = symbol_df['volume'].shift(1)
        mu_vol = shifted_volume.rolling(window=rolling_window).mean()
        sigma_vol = shifted_volume.rolling(window=rolling_window).std()
        z_vol = (symbol_df['volume'] - mu_vol) / (sigma_vol + epsilon)

        tvol = symbol_df['volume']
        taker_buy_vol = symbol_df['takerBuyBaseTvol']
        imb = (2 * taker_buy_vol - tvol) / (tvol + epsilon)
        
        signal = z_ret * z_vol * imb
        
        if not np.isnan(signal.iloc[-1]):
            final_signals[symbol] = signal.iloc[-1]

    if not final_signals:
        print("No valid signals generated.")
        return {}

    # --- Weight Allocation ---
    final_signals_series = pd.Series(final_signals)
    total_abs_signal = final_signals_series.abs().sum()
    
    if total_abs_signal == 0:
        return {}
        
    weights = final_signals_series / total_abs_signal
    
    print("\nCalculated Strategy Weights:")
    sorted_weights = sorted(weights.items(), key=lambda item: abs(item[1]), reverse=True)
    for symbol, weight in sorted_weights:
        # Print only non-zero weights
        if abs(weight) > 0:
            print(f"  {symbol}: {weight:.6f}")
            
    return weights.to_dict()

# %%
strategy(pd.DataFrame(), config_params)
# Out:
# Fetching tradable symbols...
# Successfully found 1109 tradable symbols.
# Loading available markets from Bitget...
# Found 1457 markets on Bitget.
# Fetching data for BTC/USDT...
# Fetching data for ETH/USDT...
# Fetching data for IOST/USDT...
# Fetching data for LTC/USDT...
# Fetching data for BCH/USDT...
# Fetching data for QTUM/USDT...
# Fetching data for ETC/USDT...
# Fetching data for COQ/USDT...
